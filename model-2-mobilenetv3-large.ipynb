# %% [markdown]
# <div style="
#     padding-left: 18px;
#     border-left: 4px solid #111827;
#     margin-top: 25px;
# ">
#
# <h3 style="
#     margin-bottom: 8px;
#     font-size: 24px;
#     font-weight: 600;
# "> Tahap 1 - Import Library dan Penetapan Random Seed
# </h3>
#
# <p style="
#     margin-top: 0;
#     color: #555;
#     line-height: 1.7;
# ">Tahap awal tentunya kita import semua library yang kita gunakan. Disini kita bakal pake tensorflow/keras untuk build modelnya, scikit-learn untuk evaluasi dan split dataset. Kalo di notebook sebelumnya, kita juga pake cv2 Preprocessing citra (resize, hair removal) sama matplotlib untuk visualisasi. Penetapan SEED itu gunanya agar setiap kali hasil eksperimen bisa diulang mendaptakan hasil yang sama.
# </p>
#
# </div>

# %%
#Setup & Import Library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import gc
import time
import cv2
import ctypes

#TensorFlow / Keras
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Input
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, RMSprop

#Scikit-learn
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (confusion_matrix, classification_report,
                              accuracy_score,f1_score)
from sklearn.utils.class_weight import compute_class_weight

print("import selesai")
# Out:
# 2026-06-05 05:47:48.065024: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780638468.239076      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780638468.287679      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1780638468.684623      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780638468.684669      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780638468.684672      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780638468.684675      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# import selesai

# %%
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)
print(f"Random seed: {SEED}")

print("TensorFlow version:", tf.__version__)
print("GPU tersedia:", tf.config.list_physical_devices('GPU'))
# Out:
# Random seed: 42
# TensorFlow version: 2.19.0
# GPU tersedia: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# <div style="
#     padding-left: 18px;
#     border-left: 4px solid #111827;
#     margin-top: 25px;
# ">
#
# <h3 style="
#     margin-bottom: 8px;
#     font-size: 24px;
#     font-weight: 600;
# "> Tahap 2 - Konfigurasi Hyperparameter dan Load Data
# </h3>
#
# <p style="
#     margin-top: 0;
#     color: #555;
#     line-height: 1.7;
# "> Kita define dan print hyperparameter yang kita gunakan, dan juga load data preprocesing dari hasil notebook sebelumnya
# </p>
#
# </div>

# %%
print("Path Data dan Hyperparameter")
print("=" * 50)

PATH_DATA = '/kaggle/input/notebooks/vaniaangelica/preprosessing'

# Hyperparameter
IMG_SIZE       = 224    
NUM_CLASSES    = 3      
BATCH_SIZE     = 32     
EPOCHS         = 50     
LEARNING_RATE  = 1e-4   
N_FOLDS        = 5      

print(f"Image Size    = {IMG_SIZE}")
print(f"Jumlah Kelas  = {NUM_CLASSES}")
print(f"Batch Size    = {BATCH_SIZE}")
print(f"Epoch         = {EPOCHS}")
print(f"Learning Rate = {LEARNING_RATE}")
print(f"Jumlah Fold   = {N_FOLDS}")
# Out:
# Path Data dan Hyperparameter
# ==================================================
# Image Size    = 224
# Jumlah Kelas  = 3
# Batch Size    = 32
# Epoch         = 50
# Learning Rate = 0.0001
# Jumlah Fold   = 5

# %%
print("Load Data Preprocessing")
print("=" * 50)

path_X = os.path.join(PATH_DATA, 'X_preprocessed.npy')
path_y = os.path.join(PATH_DATA, 'y_labels.npy')
X = np.load(path_X)
y_labels = np.load(path_y)

print(f"Shape X (gambar) : {X.shape}")
print(f"Shape y (label)  : {y_labels.shape}")
print(f"Tipe data X      : {X.dtype}")
print(f"Range pixel      : [{X.min()}, {X.max()}]")
print(" ")

#Tampilan jumlah per kelas
print(f"Distribusi kelas:")
for kelas in ['MEL', 'BCC', 'SCC']:
    jumlah = np.sum(y_labels == kelas)
    print(f"{kelas}: {jumlah} gambar")
# Out:
# Load Data Preprocessing
# ==================================================
# Shape X (gambar) : (8458, 224, 224, 3)
# Shape y (label)  : (8458,)
# Tipe data X      : uint8
# Range pixel      : [0, 255]
#
# Distribusi kelas:
# MEL: 4514 gambar
# BCC: 3316 gambar
# SCC: 628 gambar

# %% [markdown]
# <div style="
#     padding-left: 18px;
#     border-left: 4px solid #111827;
#     margin-top: 25px;
# ">
#
# <h3 style="
#     margin-bottom: 8px;
#     font-size: 24px;
#     font-weight: 600;
# "> Tahap 3 - Encode Label dan Undersampling
# </h3>
#
# <p style="
#     margin-top: 0;
#     color: #555;
#     line-height: 1.7;
# "> Disini kita bakal lihat contoh persebaran pixel terus juga encode label pakai one-hot-encode
#     dan karena kelas kita imbalanced kita undersampling kelas melanoma dan bcc.
# </p>
#
# </div>

# %%
"""
Encode dilakukan untuk mengubah label kelas string menjadi bentuk numerik.
Di sini kita lebih memakai one-hot encoding, dimana 
numerik yang terbentuk mirip seperti kolom biner.

Namun pengubahan menjadi one-hot encoding akan dilakukan dalam loop training. 
Pada cell ini one-hot encoding yang di keluarkan sebagai contoh saja,
karena y_encode yang disini akan di overide pada bagian undersampling nanti. 
"""

LabelEncode = LabelEncoder()
y_encoded = LabelEncode.fit_transform(y_labels) 

print("Mapping Label:")
print(" ")
for i, nama_kelas in enumerate(LabelEncode.classes_):
    jumlah = np.sum(y_encoded == i)
    print(f"{nama_kelas} : {i} ({jumlah} gambar)")

# One-Hot Encoding
y_onehot = to_categorical(y_encoded, num_classes=NUM_CLASSES)

print(f"Shape y_encoded : {y_encoded.shape}")
print(f"Shape y_onehot  : {y_onehot.shape}")

print(" ")
print(f"Contoh encoding (3 gambar pertama):")
for i in range(3):
    print(f"    '{y_labels[i]}' → {y_encoded[i]} → {y_onehot[i]}")
# Out:
# Mapping Label:
#
# BCC : 0 (3316 gambar)
# MEL : 1 (4514 gambar)
# SCC : 2 (628 gambar)
# Shape y_encoded : (8458,)
# Shape y_onehot  : (8458, 3)
#
# Contoh encoding (3 gambar pertama):
#     'MEL' → 1 → [0. 1. 0.]
#     'MEL' → 1 → [0. 1. 0.]
#     'MEL' → 1 → [0. 1. 0.]

# %%
print("RANDOM UNDERSAMPLING")
print("=" * 50)

# Distribusi sebelum undersampling 
print(" ")
print("Distribusi Sebelum Undersampling:")
y_labels_asli  = np.load(os.path.join(PATH_DATA, 'y_labels.npy'))
y_encoded_asli = LabelEncode.transform(y_labels_asli)

jumlah_per_kelas_awal = []
for i, nama in enumerate(LabelEncode.classes_):
    jumlah = int(np.sum(y_encoded_asli == i))
    jumlah_per_kelas_awal.append(jumlah)
    print(f"{nama}: {jumlah} gambar")

#Target jumlah kelas 
target_per_kelas = {
    0: 2000,  
    1: 2000,  
    2: 628    
}

#Random undersample setiap kelas
np.random.seed(SEED)

idx_under = []
for i in range(NUM_CLASSES):
    idx_kelas = np.where(y_encoded == i)[0]
    target    = target_per_kelas[i]

    if len(idx_kelas) <= target:
        idx_dipilih = idx_kelas #semua kelas SCC diambil
    else:
        idx_dipilih = np.random.choice(idx_kelas, size=target, replace=False)

    idx_under.extend(idx_dipilih.tolist())

# Shuffle agar urutan kelas tidak berurutan
idx_under = np.array(idx_under)
np.random.shuffle(idx_under)

#Buat array baru
X_under       = X[idx_under]           # gambar hasil undersample
y_under       = y_encoded[idx_under]   # label integer
y_labels_under = y_labels[idx_under]   # label teks (MEL/BCC/SCC)

#Distribusi Sesudah Undersampling
print(" ")
print("Distribusi Sesudah Undersampling:")
jumlah_per_kelas_akhir = []
for i, nama in enumerate(LabelEncode.classes_):
    jumlah = int(np.sum(y_under == i))
    jumlah_per_kelas_akhir.append(jumlah)
    print(f"{nama} ({i}): {jumlah} gambar")
print(f"Total : {len(y_under)} gambar")

#Visualisasi
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
fig.suptitle('Distribusi Dataset: Sebelum dan Sesudah Undersampling',fontsize=13, fontweight='bold')

nama_kelas_list = list(LabelEncode.classes_)
warna = ['#00746c', '#4f9f2c', '#ffa600']

# Sebelum undersampling
axes[0].bar(nama_kelas_list, jumlah_per_kelas_awal, color=warna, edgecolor='black')
axes[0].set_title('Sebelum Undersampling', fontweight='bold')
axes[0].set_xlabel('Kelas')
axes[0].set_ylabel('Jumlah Gambar')
axes[0].set_ylim(0, max(jumlah_per_kelas_awal) * 1.15)
for i, v in enumerate(jumlah_per_kelas_awal):
    axes[0].text(i, v + max(jumlah_per_kelas_awal) * 0.02, str(v),ha='center', fontweight='bold')

# Sesudah undersampling
axes[1].bar(nama_kelas_list, jumlah_per_kelas_akhir, color=warna, edgecolor='black')
axes[1].set_title('Sesudah Undersampling', fontweight='bold')
axes[1].set_xlabel('Kelas')
axes[1].set_ylabel('Jumlah Gambar')
axes[1].set_ylim(0, max(jumlah_per_kelas_akhir) * 1.15)
for i, v in enumerate(jumlah_per_kelas_akhir):
    axes[1].text(i, v + max(jumlah_per_kelas_akhir) * 0.02, str(v),ha='center', fontweight='bold')

plt.tight_layout()
plt.show()

#Override variabel utama 
X         = X_under
y_encoded = y_under
y_labels  = y_labels_under

print("\nVariabel X, y_encoded, y_labels yang sudah di replace.")
print(f"Shape X baru    : {X.shape}")
print(f"Shape y baru    : {y_encoded.shape}")
# Out:
# RANDOM UNDERSAMPLING
# ==================================================
#
# Distribusi Sebelum Undersampling:
# BCC: 3316 gambar
# MEL: 4514 gambar
# SCC: 628 gambar
#
# Distribusi Sesudah Undersampling:
# BCC (0): 2000 gambar
# MEL (1): 2000 gambar
# SCC (2): 628 gambar
# Total : 4628 gambar
# Variabel X, y_encoded, y_labels yang sudah di replace.
# Shape X baru    : (4628, 224, 224, 3)
# Shape y baru    : (4628,)

# %% [markdown]
# <div style="
#     padding-left: 18px;
#     border-left: 4px solid #111827;
#     margin-top: 25px;
# ">
#
# <h3 style="
#     margin-bottom: 8px;
#     font-size: 24px;
#     font-weight: 600;
# "> Tahap 4 - Augmentasi Citra
# </h3>
#
# <p style="
#     margin-top: 0;
#     color: #555;
#     line-height: 1.7;
# "> Kita define dan print hyperparameter yang kita gunakan, dan juga load data preprocesing dari hasil notebook sebelumnya
# </p>
#
# </div>

# %%
#Tujuan augmentasi data ini untuk variasi data
#saat masuk ke loop training 
print("Augmentasi hanya untuk data training")
print("Data validasi tidak di augmentasi")

#Augmentasi untuk data TRAINING
train_datagen = ImageDataGenerator(
    rotation_range=180,           # Rotasi acak 0-180 derajat
    width_shift_range=0.1,        # Geser horizontal 10%
    height_shift_range=0.1,       # Geser vertikal 10%
    zoom_range=0.1,               # Zoom in/out 10%
    horizontal_flip=True,         # Flip horizontal
    vertical_flip=True,           # Flip vertikal
    fill_mode='nearest'           # Isi piksel kosong dengan piksel terdekat
)

# Untuk data validasi, tanpa augmentasi (data asli saja)
val_datagen = ImageDataGenerator()
# Out:
# Augmentasi hanya untuk data training
# Data validasi tidak di augmentasi

# %%
print("Contoh Augmentasi")
print("=" * 50)

#disini kita laukakan augmentasi on-the=fly
gambar_contoh = X[0:1] 

daftar_augmentasi = [
    ('Rotasi 90°',        ImageDataGenerator(rotation_range=90)),
    ('Rotasi 180°',       ImageDataGenerator(rotation_range=180)),
    ('Width Shift 10%',   ImageDataGenerator(width_shift_range=0.1)),
    ('Height Shift 10%',  ImageDataGenerator(height_shift_range=0.1)),
    ('Zoom In/Out 10%',   ImageDataGenerator(zoom_range=0.1)),
    ('Flip Horizontal',   ImageDataGenerator(horizontal_flip=True)),
    ('Flip Vertikal',     ImageDataGenerator(vertical_flip=True)),
]

fig, axes = plt.subplots(2, 4, figsize=(15, 7))
fig.suptitle('Contoh Augmentasi: 1 Gambar Asli dan 7 Jenis Transformasi',
             fontsize=13, fontweight='bold')

# Gambar asli
axes[0, 0].imshow(gambar_contoh[0])
axes[0, 0].set_title('ORIGINAL', fontweight='bold', color='red')
axes[0, 0].axis('off')

# 7 jenis augmentasi
for i, (nama_aug, datagen) in enumerate(daftar_augmentasi):
    baris = (i + 1) // 4
    kolom = (i + 1) % 4
    aug_iter = datagen.flow(gambar_contoh, batch_size=1)
    
    #Ambil gambar augmentasi
    gambar_aug = next(aug_iter)[0]
    
    #Cast float32 [0, 255] kembali ke uint8
    gambar_aug_tampil = gambar_aug.astype('uint8')
    
    axes[baris, kolom].imshow(gambar_aug_tampil)
    axes[baris, kolom].set_title(nama_aug, fontsize=10, fontweight='bold')
    axes[baris, kolom].axis('off')

plt.tight_layout()
plt.show()
# Out:
# Contoh Augmentasi
# ==================================================

# %% [markdown]
# <div style="
#     padding-left: 18px;
#     border-left: 4px solid #111827;
#     margin-top: 25px;
# ">
#
# <h3 style="
#     margin-bottom: 8px;
#     font-size: 24px;
#     font-weight: 600;
# "> Tahap 5 - Rancangan Model
# </h3>
#
# <p style="
#     margin-top: 0;
#     color: #555;
#     line-height: 1.7;
# "> Selanjutnya kita akan menampilkan model yang akan kita gunakan dan dijelaskan dalam bentuk model demo. Disini kita juga membuat fungsi untuk memilih optimizer dan setup stratified k-fold.</p>
#
# </div>

# %%
print("Arsitektur Model")
print("=" * 50)

def buat_model():
    
    #Kita load base model pretraid dan buang classification head bawaan
    #Buang head = "include_top=False"
    #Backbone tidak di train = "base_model.trainable = False"
    base_model = MobileNetV3Large(
        weights='imagenet',
        include_top=False,
        input_shape=(IMG_SIZE, IMG_SIZE, 3)
    )
    base_model.trainable = False

    #Pakai pakai input/output milik base_model
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(NUM_CLASSES, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=outputs)
    return model

#Menampilkan arsitektur
model_demo = buat_model()
model_demo.summary()

#Verifikasi nama layer Conv2D terakhir untuk GradCAM
print("\nVerifikasi target layer GradCAM:")
for layer in reversed(model_demo.layers):
    if isinstance(layer, tf.keras.layers.Conv2D):
        GRADCAM_LAYER = layer.name
        print(f"Conv2D terakhir : '{GRADCAM_LAYER}'")
        print(f"Output shape    : {layer.output.shape}")
        break
        
print(" ")
print(f"GradCam Layer : '{GRADCAM_LAYER}'")

#Hitung jumlah parameter
total_params     = model_demo.count_params()
trainable_params = sum([tf.keras.backend.count_params(w)
                        for w in model_demo.trainable_weights])
frozen_params    = total_params - trainable_params

print(f"\nTotal parameter   : {total_params:,}")
print(f"Parameter dilatih : {trainable_params:,}")
print(f"Parameter frozen  : {frozen_params:,}")

#hapus model demo biar memori ngga penuh
del model_demo
gc.collect()
tf.keras.backend.clear_session()
# Out:
# Arsitektur Model
# ==================================================
# I0000 00:00:1780638491.590620      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 224, 224,  │          0 │ input_layer[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv (Conv2D)       │ (None, 112, 112,  │        432 │ rescaling[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_bn             │ (None, 112, 112,  │         64 │ conv[0][0]        │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 112, 112,  │          0 │ conv_bn[0][0]     │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │        144 │ activation[0][0]  │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │         64 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 112, 112,  │          0 │ expanded_conv_de… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │        256 │ re_lu[0][0]       │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_add   │ (None, 112, 112,  │          0 │ activation[0][0], │
# │ (Add)               │ 16)               │            │ expanded_conv_pr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 112, 112,  │      1,024 │ expanded_conv_ad… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 112, 112,  │        256 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 112, 112,  │          0 │ expanded_conv_1_… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 113, 113,  │          0 │ re_lu_1[0][0]     │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 56, 56,    │        576 │ expanded_conv_1_… │
# │ (DepthwiseConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 56, 56,    │        256 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_1_… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 56, 56,    │      1,536 │ re_lu_2[0][0]     │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 56, 56,    │         96 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 56, 56,    │      1,728 │ expanded_conv_1_… │
# │ (Conv2D)            │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 56, 56,    │        288 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_2_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 56, 56,    │        648 │ re_lu_3[0][0]     │
# │ (DepthwiseConv2D)   │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 56, 56,    │        288 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_2_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 56, 56,    │      1,728 │ re_lu_4[0][0]     │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 56, 56,    │         96 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_add │ (None, 56, 56,    │          0 │ expanded_conv_1_… │
# │ (Add)               │ 24)               │            │ expanded_conv_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 56, 56,    │      1,728 │ expanded_conv_2_… │
# │ (Conv2D)            │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 56, 56,    │        288 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_3_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 59, 59,    │          0 │ re_lu_5[0][0]     │
# │ (ZeroPadding2D)     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 28, 28,    │      1,800 │ expanded_conv_3_… │
# │ (DepthwiseConv2D)   │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 28, 28,    │        288 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_3_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 72)  │          0 │ re_lu_6[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 24)  │      1,752 │ expanded_conv_3_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 24)  │          0 │ expanded_conv_3_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 72)  │      1,800 │ expanded_conv_3_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 1, 1, 72)  │          0 │ expanded_conv_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 1, 1, 72)  │          0 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 1, 1, 72)  │          0 │ re_lu_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 28, 28,    │          0 │ re_lu_6[0][0],    │
# │ (Multiply)          │ 72)               │            │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 28, 28,    │      2,880 │ expanded_conv_3_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 28, 28,    │        160 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 28, 28,    │      4,800 │ expanded_conv_3_… │
# │ (Conv2D)            │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 28, 28,    │        480 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_4_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_de… │ (None, 28, 28,    │      3,000 │ re_lu_8[0][0]     │
# │ (DepthwiseConv2D)   │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_de… │ (None, 28, 28,    │        480 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_4_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 120) │          0 │ re_lu_9[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 32)  │      3,872 │ expanded_conv_4_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 32)  │          0 │ expanded_conv_4_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 120) │      3,960 │ expanded_conv_4_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 1, 1, 120) │          0 │ expanded_conv_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 1, 1, 120) │          0 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 1, 1, 120) │          0 │ re_lu_10[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 28, 28,    │          0 │ re_lu_9[0][0],    │
# │ (Multiply)          │ 120)              │            │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_pr… │ (None, 28, 28,    │      4,800 │ expanded_conv_4_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_pr… │ (None, 28, 28,    │        160 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_add │ (None, 28, 28,    │          0 │ expanded_conv_3_… │
# │ (Add)               │ 40)               │            │ expanded_conv_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_ex… │ (None, 28, 28,    │      4,800 │ expanded_conv_4_… │
# │ (Conv2D)            │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_ex… │ (None, 28, 28,    │        480 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 28, 28,    │          0 │ expanded_conv_5_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_de… │ (None, 28, 28,    │      3,000 │ re_lu_11[0][0]    │
# │ (DepthwiseConv2D)   │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_de… │ (None, 28, 28,    │        480 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 28, 28,    │          0 │ expanded_conv_5_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 120) │          0 │ re_lu_12[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 32)  │      3,872 │ expanded_conv_5_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 32)  │          0 │ expanded_conv_5_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 120) │      3,960 │ expanded_conv_5_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 1, 1, 120) │          0 │ expanded_conv_5_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 1, 1, 120) │          0 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 1, 1, 120) │          0 │ re_lu_13[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 28, 28,    │          0 │ re_lu_12[0][0],   │
# │ (Multiply)          │ 120)              │            │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_pr… │ (None, 28, 28,    │      4,800 │ expanded_conv_5_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_pr… │ (None, 28, 28,    │        160 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_add │ (None, 28, 28,    │          0 │ expanded_conv_4_… │
# │ (Add)               │ 40)               │            │ expanded_conv_5_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_ex… │ (None, 28, 28,    │      9,600 │ expanded_conv_5_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_ex… │ (None, 28, 28,    │        960 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 28, 28,    │          0 │ expanded_conv_6_… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 29, 29,    │          0 │ activation_1[0][… │
# │ (ZeroPadding2D)     │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 14, 14,    │      2,160 │ expanded_conv_6_… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 14, 14,    │        960 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_pr… │ (None, 14, 14,    │     19,200 │ activation_2[0][… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_pr… │ (None, 14, 14,    │        320 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_ex… │ (None, 14, 14,    │     16,000 │ expanded_conv_6_… │
# │ (Conv2D)            │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_ex… │ (None, 14, 14,    │        800 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Activation)        │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_de… │ (None, 14, 14,    │      1,800 │ activation_3[0][… │
# │ (DepthwiseConv2D)   │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_de… │ (None, 14, 14,    │        800 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Activation)        │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_pr… │ (None, 14, 14,    │     16,000 │ activation_4[0][… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_pr… │ (None, 14, 14,    │        320 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_add │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │ (Add)               │ 80)               │            │ expanded_conv_7_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_ex… │ (None, 14, 14,    │     14,720 │ expanded_conv_7_… │
# │ (Conv2D)            │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_ex… │ (None, 14, 14,    │        736 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 14, 14,    │      1,656 │ activation_5[0][… │
# │ (DepthwiseConv2D)   │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 14, 14,    │        736 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_pr… │ (None, 14, 14,    │     14,720 │ activation_6[0][… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_pr… │ (None, 14, 14,    │        320 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_add │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Add)               │ 80)               │            │ expanded_conv_8_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_ex… │ (None, 14, 14,    │     14,720 │ expanded_conv_8_… │
# │ (Conv2D)            │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_ex… │ (None, 14, 14,    │        736 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 14, 14,    │          0 │ expanded_conv_9_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_de… │ (None, 14, 14,    │      1,656 │ activation_7[0][… │
# │ (DepthwiseConv2D)   │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_de… │ (None, 14, 14,    │        736 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 14, 14,    │          0 │ expanded_conv_9_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_pr… │ (None, 14, 14,    │     14,720 │ activation_8[0][… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_pr… │ (None, 14, 14,    │        320 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_add │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │ (Add)               │ 80)               │            │ expanded_conv_9_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_e… │ (None, 14, 14,    │     38,400 │ expanded_conv_9_… │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_e… │ (None, 14, 14,    │      1,920 │ expanded_conv_10… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 14, 14,    │          0 │ expanded_conv_10… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_d… │ (None, 14, 14,    │      4,320 │ activation_9[0][… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_d… │ (None, 14, 14,    │      1,920 │ expanded_conv_10… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 14, 14,    │          0 │ expanded_conv_10… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 480) │          0 │ activation_10[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 120) │     57,720 │ expanded_conv_10… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 120) │          0 │ expanded_conv_10… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 480) │     58,080 │ expanded_conv_10… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 1, 1, 480) │          0 │ expanded_conv_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 1, 1, 480) │          0 │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 1, 1, 480) │          0 │ re_lu_14[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 14, 14,    │          0 │ activation_10[0]… │
# │ (Multiply)          │ 480)              │            │ multiply_3[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_p… │ (None, 14, 14,    │     53,760 │ expanded_conv_10… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_p… │ (None, 14, 14,    │        448 │ expanded_conv_10… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_e… │ (None, 14, 14,    │     75,264 │ expanded_conv_10… │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_e… │ (None, 14, 14,    │      2,688 │ expanded_conv_11… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 14, 14,    │          0 │ expanded_conv_11… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_d… │ (None, 14, 14,    │      6,048 │ activation_11[0]… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_d… │ (None, 14, 14,    │      2,688 │ expanded_conv_11… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 14, 14,    │          0 │ expanded_conv_11… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 672) │          0 │ activation_12[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 168) │    113,064 │ expanded_conv_11… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 168) │          0 │ expanded_conv_11… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 672) │    113,568 │ expanded_conv_11… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 1, 1, 672) │          0 │ expanded_conv_11… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 1, 1, 672) │          0 │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_4          │ (None, 1, 1, 672) │          0 │ re_lu_15[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 14, 14,    │          0 │ activation_12[0]… │
# │ (Multiply)          │ 672)              │            │ multiply_4[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_p… │ (None, 14, 14,    │     75,264 │ expanded_conv_11… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_p… │ (None, 14, 14,    │        448 │ expanded_conv_11… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_a… │ (None, 14, 14,    │          0 │ expanded_conv_10… │
# │ (Add)               │ 112)              │            │ expanded_conv_11… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_e… │ (None, 14, 14,    │     75,264 │ expanded_conv_11… │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_e… │ (None, 14, 14,    │      2,688 │ expanded_conv_12… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 14, 14,    │          0 │ expanded_conv_12… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_d… │ (None, 17, 17,    │          0 │ activation_13[0]… │
# │ (ZeroPadding2D)     │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_d… │ (None, 7, 7, 672) │     16,800 │ expanded_conv_12… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_d… │ (None, 7, 7, 672) │      2,688 │ expanded_conv_12… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 7, 7, 672) │          0 │ expanded_conv_12… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 672) │          0 │ activation_14[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 168) │    113,064 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 168) │          0 │ expanded_conv_12… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 672) │    113,568 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 1, 1, 672) │          0 │ expanded_conv_12… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 1, 1, 672) │          0 │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_5          │ (None, 1, 1, 672) │          0 │ re_lu_16[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 7, 7, 672) │          0 │ activation_14[0]… │
# │ (Multiply)          │                   │            │ multiply_5[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_p… │ (None, 7, 7, 160) │    107,520 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_p… │ (None, 7, 7, 160) │        640 │ expanded_conv_12… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_e… │ (None, 7, 7, 960) │    153,600 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_e… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_13… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 7, 7, 960) │          0 │ expanded_conv_13… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_d… │ (None, 7, 7, 960) │     24,000 │ activation_15[0]… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_d… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_13… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 7, 7, 960) │          0 │ expanded_conv_13… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 1, 1, 960) │          0 │ activation_16[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 1, 1, 240) │    230,640 │ expanded_conv_13… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 1, 1, 240) │          0 │ expanded_conv_13… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 1, 1, 960) │    231,360 │ expanded_conv_13… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 1, 1, 960) │          0 │ expanded_conv_13… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 1, 1, 960) │          0 │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_6          │ (None, 1, 1, 960) │          0 │ re_lu_17[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 7, 7, 960) │          0 │ activation_16[0]… │
# │ (Multiply)          │                   │            │ multiply_6[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_p… │ (None, 7, 7, 160) │    153,600 │ expanded_conv_13… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_p… │ (None, 7, 7, 160) │        640 │ expanded_conv_13… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_a… │ (None, 7, 7, 160) │          0 │ expanded_conv_12… │
# │ (Add)               │                   │            │ expanded_conv_13… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_e… │ (None, 7, 7, 960) │    153,600 │ expanded_conv_13… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_e… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_14… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 7, 7, 960) │          0 │ expanded_conv_14… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_d… │ (None, 7, 7, 960) │     24,000 │ activation_17[0]… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_d… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_14… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 7, 7, 960) │          0 │ expanded_conv_14… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 1, 1, 960) │          0 │ activation_18[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 1, 1, 240) │    230,640 │ expanded_conv_14… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 1, 1, 240) │          0 │ expanded_conv_14… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 1, 1, 960) │    231,360 │ expanded_conv_14… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 1, 1, 960) │          0 │ expanded_conv_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_18 (ReLU)     │ (None, 1, 1, 960) │          0 │ add_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_7          │ (None, 1, 1, 960) │          0 │ re_lu_18[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 7, 7, 960) │          0 │ activation_18[0]… │
# │ (Multiply)          │                   │            │ multiply_7[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_p… │ (None, 7, 7, 160) │    153,600 │ expanded_conv_14… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_p… │ (None, 7, 7, 160) │        640 │ expanded_conv_14… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_a… │ (None, 7, 7, 160) │          0 │ expanded_conv_13… │
# │ (Add)               │                   │            │ expanded_conv_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1 (Conv2D)     │ (None, 7, 7, 960) │    153,600 │ expanded_conv_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1_bn           │ (None, 7, 7, 960) │      3,840 │ conv_1[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 7, 7, 960) │          0 │ conv_1_bn[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 960)       │          0 │ activation_19[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │    246,016 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 3)         │        771 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,243,139 (12.37 MB)
#  Trainable params: 246,787 (964.01 KB)
#  Non-trainable params: 2,996,352 (11.43 MB)
# Verifikasi target layer GradCAM:
# Conv2D terakhir : 'conv_1'
# Output shape    : (None, 7, 7, 960)
#
# GradCam Layer : 'conv_1'
#
# Total parameter   : 3,243,139
# Parameter dilatih : 246,787
# Parameter frozen  : 2,996,352

# %%
print("Optimizer")
print("=" * 50)

def pilih_optimizer(nama_optimizer):
    if nama_optimizer == 'Adam':
        return Adam(learning_rate=LEARNING_RATE)
    elif nama_optimizer == 'RMSprop':
        return RMSprop(learning_rate=LEARNING_RATE)
    else: 
        raise ValueError(f"Optimizer '{nama_optimizer}' tidak dikenal. "
                         f"Pilih: 'Adam' atau 'RMSprop'")

# Daftar optimizer yang akan dibandingkan
daftar_optimizer = ['Adam', 'RMSprop']
print(f"Optimizer yang akan dibandingkan: {daftar_optimizer}")
# Out:
# Optimizer
# ==================================================
# Optimizer yang akan dibandingkan: ['Adam', 'RMSprop']

# %%
print("Focal Loss")
print("=" * 50)

# Alpha otomatis proporsional dengan distribusi 2000:2000:628
bobot_kelas_raw = compute_class_weight(
    'balanced',
    classes=np.unique(y_encoded),
    y=y_encoded
)

#pake Alpha apa adanya
bobot_kelas = bobot_kelas_raw.tolist()

focal_loss_function = tf.keras.losses.CategoricalFocalCrossentropy(
    alpha=bobot_kelas,
    gamma=2.0
)

print("Alpha per kelas:")
for i, nama in enumerate(LabelEncode.classes_):
    print(f"{nama}: {bobot_kelas_raw[i]:.4f}")
print(f"\nGamma : 2.0")
# Out:
# Focal Loss
# ==================================================
# Alpha per kelas:
# BCC: 0.7713
# MEL: 0.7713
# SCC: 2.4565
#
# Gamma : 2.0

# %%
skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=SEED)
splits = list(skf.split(X, y_encoded))

print(f"Stratified {N_FOLDS}-Fold Validation")
print("=" * 55)
print(f"Total data: {len(y_encoded)} gambar, dibagi {N_FOLDS} fold")
print( )

# Tampilkan isi tiap fold
for fold in range(N_FOLDS):
    _, idx_val = splits[fold]
    y_val = y_encoded[idx_val]
    detail = ", ".join(
        f"{LabelEncode.classes_[i]}={np.sum(y_val==i)}"
        for i in range(NUM_CLASSES)
    )
    print(f"  Fold {fold+1}: {len(idx_val)} gambar  [{detail}]")


print("-" * 55 )
# Tampilkan tiap iterasi training
for fold, (idx_train, idx_val) in enumerate(splits):
    y_train_fold = y_encoded[idx_train]
    y_val_fold   = y_encoded[idx_val]

    fold_training = "+".join(f"Fold {j+1}" for j in range(N_FOLDS) if j != fold)
    detail_val   = ", ".join(
        f"{LabelEncode.classes_[i]}={np.sum(y_val_fold==i)}"
        for i in range(NUM_CLASSES)
    )
    detail_train = ", ".join(
        f"{LabelEncode.classes_[i]}={np.sum(y_train_fold==i)}"
        for i in range(NUM_CLASSES)
    )

    print(f"Iterasi {fold+1}: [Fold {fold+1} = VALIDASI]  [{fold_training} = TRAINING]")
    print(f"  Validasi : {len(idx_val):4d} gambar  [{detail_val}]")
    print(f"  Training : {len(idx_train):4d} gambar  [{detail_train}]")
    print()
# Out:
# Stratified 5-Fold Validation
# =======================================================
# Total data: 4628 gambar, dibagi 5 fold
#
#   Fold 1: 926 gambar  [BCC=400, MEL=400, SCC=126]
#   Fold 2: 926 gambar  [BCC=400, MEL=400, SCC=126]
#   Fold 3: 926 gambar  [BCC=400, MEL=400, SCC=126]
#   Fold 4: 925 gambar  [BCC=400, MEL=400, SCC=125]
#   Fold 5: 925 gambar  [BCC=400, MEL=400, SCC=125]
# -------------------------------------------------------
# Iterasi 1: [Fold 1 = VALIDASI]  [Fold 2+Fold 3+Fold 4+Fold 5 = TRAINING]
#   Validasi :  926 gambar  [BCC=400, MEL=400, SCC=126]
#   Training : 3702 gambar  [BCC=1600, MEL=1600, SCC=502]
#
# Iterasi 2: [Fold 2 = VALIDASI]  [Fold 1+Fold 3+Fold 4+Fold 5 = TRAINING]
#   Validasi :  926 gambar  [BCC=400, MEL=400, SCC=126]
#   Training : 3702 gambar  [BCC=1600, MEL=1600, SCC=502]
#
# Iterasi 3: [Fold 3 = VALIDASI]  [Fold 1+Fold 2+Fold 4+Fold 5 = TRAINING]
#   Validasi :  926 gambar  [BCC=400, MEL=400, SCC=126]
#   Training : 3702 gambar  [BCC=1600, MEL=1600, SCC=502]
#
# Iterasi 4: [Fold 4 = VALIDASI]  [Fold 1+Fold 2+Fold 3+Fold 5 = TRAINING]
#   Validasi :  925 gambar  [BCC=400, MEL=400, SCC=125]
#   Training : 3703 gambar  [BCC=1600, MEL=1600, SCC=503]
#
# Iterasi 5: [Fold 5 = VALIDASI]  [Fold 1+Fold 2+Fold 3+Fold 4 = TRAINING]
#   Validasi :  925 gambar  [BCC=400, MEL=400, SCC=125]
#   Training : 3703 gambar  [BCC=1600, MEL=1600, SCC=503]

# %% [markdown]
# <div style="
#     padding-left: 18px;
#     border-left: 4px solid #111827;
#     margin-top: 25px;
# ">
#
# <h3 style="
#     margin-bottom: 8px;
#     font-size: 24px;
#     font-weight: 600;
# "> Tahap 6 - Training Model
# </h3>
#
# <p style="
#     margin-top: 0;
#     color: #555;
#     line-height: 1.7;
# "> Setelah semua sudah di define, sekarang  kita akan melakukan training model.</p>
#
# </div>

# %%
print("Membuat KFoldDataGenerator")
print("=" * 50)

from tensorflow.keras.utils import Sequence
import math

class KFoldDataGenerator(Sequence):
    
    """
    Custom Data Generator untuk Stratified K-Fold.
    Mengambil data per-batch (~18 MB) dari X uint8 langsung,
    tanpa menyalin seluruh data training ke memori.

    Alur per-batch:
      X uint8 - float32 - augmentasi - preprocess_input - [-1, 1]
    
    Parameter:
        X_sumber   : array gambar utama, X uint8 asli
        y_sumber   : array label one-hot untuk seluruh data
        indices    : daftar indeks gambar untuk fold ini
        batch_size : jumlah gambar per batch
        datagen    : ImageDataGenerator untuk augmentasi (None = tanpa augmentasi)
        shuffle    : acak urutan data setiap epoch
    """
    
    def __init__(self, X_sumber, y_sumber, indices, 
                 batch_size, datagen=None, shuffle=True):
        self.X_sumber = X_sumber
        self.y_sumber = y_sumber
        self.indices = indices.copy()
        self.batch_size = batch_size
        self.datagen = datagen
        self.shuffle = shuffle
        self.on_epoch_end()
        
    def __len__(self):
        return math.ceil(len(self.indices) / self.batch_size)
        
    def __getitem__(self, idx):
        # Ambil indeks untuk batch ini
        batch_idx = self.indices[idx * self.batch_size : (idx + 1) * self.batch_size]
        
        # Ambil batch & konversi ke float32
        # .astype() membuat array baru (tidak modifikasi X asli)
        batch_x = self.X_sumber[batch_idx].astype(np.float32)  # [0, 255] float32
        batch_y = self.y_sumber[batch_idx]
        
       # Pertama, Augmentasi dulu untuk training
        # datagen.flow() lebih cepat dari loop random_transform satu-per-satu
        if self.datagen is not None:
            batch_x = next(
                self.datagen.flow(batch_x,
                                  batch_size=len(batch_x),
                                  shuffle=False)   # shuffle=False, urutan sudah diatur
            )
        
        # Kedua, normalisasi setelah augmentasi
        # preprocess_input: [0, 255] → [-1, 1]  
        batch_x = preprocess_input(batch_x)
                
        return batch_x, batch_y

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

print("KFoldDataGenerator siap!")
# Out:
# Membuat KFoldDataGenerator
# ==================================================
# KFoldDataGenerator siap!

# %%
print("Training Model")
print("=" * 50)

hasil = {}
for nama_opt in daftar_optimizer:
    hasil[nama_opt] = {
        'history'      : [],   # History training per fold
        'val_acc'      : [],   # Best val accuracy per fold
        'val_macro_f1' : [],   # Macro F1 per fold
        'y_true'       : [],   # Label asli (dari semua fold, digabung)
        'y_pred'       : [],   # Label prediksi (dari semua fold, digabung)
        'y_true_fold'  : [],   
        'y_pred_fold'  : [],   
    }

# Variabel untuk menyimpan model terbaik secara keseluruhan
best_acc_per_optimizer   = {nama: 0.0 for nama in daftar_optimizer}  
best_model_info_per_opt  = {}              

#One-Hot Encoding untuk seluruh data (dipakai oleh generator)
y_encoded_oh = to_categorical(y_encoded, NUM_CLASSES)

waktu_mulai_total = time.time()

# LOOP TRAINING UTAMA 
for nama_opt in daftar_optimizer:

    print(f"\n{'—'*55}")
    print(f"OPTIMIZER: {nama_opt}")
    print(f"{'—'*55}")

    waktu_mulai_opt = time.time()

    for fold, (idx_train, idx_val) in enumerate(skf.split(X, y_encoded)):

        tf.keras.backend.clear_session()
        gc.collect()

        print(f"\n  --- Fold {fold+1}/{N_FOLDS} ({nama_opt}) ---")

        # 1. kita ambil label untuk menampilkan distribusi
        y_train = y_encoded[idx_train]

        # Menampilkan kelas di fold yang sedang berjalan
        print(f"  Distribusi Training:")
        for kls in np.unique(y_train):
            print(f"    {LabelEncode.classes_[kls]}: {np.sum(y_train == kls)}")
        print(f"  Total Training: {len(y_train)} | Validation: {len(idx_val)}")

        # 2. Buat Generator Training
        train_generator = KFoldDataGenerator(
            X_sumber=X,
            y_sumber=y_encoded_oh,
            indices=idx_train,
            batch_size=BATCH_SIZE,
            datagen=train_datagen,
            shuffle=True
        )

        # 3. Siapkan data validasi
        val_generator = KFoldDataGenerator(
            X_sumber=X,
            y_sumber=y_encoded_oh,
            indices=idx_val,
            batch_size=BATCH_SIZE,
            datagen=None,      # valiadsi tanpa augmentasi
            shuffle=False      # validasi tidak perlu di-shuffle
        )
        
        # 4. Buat model baru
        model = buat_model()

        # 5. Compile model dengan focal loss
        optimizer = pilih_optimizer(nama_opt)
        model.compile(
            optimizer=optimizer,
            loss= focal_loss_function,
            metrics=['accuracy']
        )

        # 6. Callbacks 
        # Early Stopping
        early_stop = EarlyStopping(
            monitor='val_loss',
            patience=5,
            min_delta=1e-4,  
            restore_best_weights=True,
            verbose=1
        )

        # ReduceLROnPlateau
        reduce_lr = ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=3,
            min_delta=1e-4, 
            min_lr=1e-6,
            verbose=1
        )

        # 7. Training Dataset
        # Disini generator memberikan data per-batch dengan augmentasi on-the-fly
        print(f"Mulai training...")
        history = model.fit(
            train_generator,
            validation_data=val_generator,
            epochs=EPOCHS,
            callbacks=[early_stop, reduce_lr],
            verbose=1
        )

        # 8. Evaluasi pada validation set
        y_pred_proba = model.predict(val_generator, verbose=0)
        y_pred       = np.argmax(y_pred_proba, axis=1)
        y_val_true   = np.argmax(y_encoded_oh[idx_val], axis=1)
        val_acc      = accuracy_score(y_val_true, y_pred)
        val_macro_f1 = f1_score(y_val_true, y_pred, average='macro')

        print(f" Fold {fold+1} selesai!")
        print(f"  Val Accuracy : {val_acc:.4f}")
        print(f"  Val Macro F1 : {val_macro_f1:.4f}")

        # 9. Simpan hasil
        hasil[nama_opt]['history'].append(history.history)
        hasil[nama_opt]['val_acc'].append(val_acc)
        hasil[nama_opt]['val_macro_f1'].append(val_macro_f1)
        hasil[nama_opt]['y_true'].extend(y_val_true.tolist())
        hasil[nama_opt]['y_pred'].extend(y_pred.tolist())
        hasil[nama_opt]['y_true_fold'].append(list(y_val_true))
        hasil[nama_opt]['y_pred_fold'].append(list(y_pred))

        # 10. Cek apakah ini model terbaik secara keseluruhan
        if val_acc > best_acc_per_optimizer[nama_opt]:
            best_acc_per_optimizer[nama_opt] = val_acc
            best_model_info_per_opt[nama_opt] = {
                'optimizer'    : nama_opt,
                'fold'         : fold + 1,
                'val_acc'      : val_acc,
                'val_macro_f1' : val_macro_f1,
            }
    
            # Simpan model terbaik
            model.save(f'/kaggle/working/model_terbaik_mobilenetv3_partial_LR2{nama_opt}.keras')
            print(f">>> Model Terbaik Baru untuk {nama_opt} (Accuracy={val_acc:.4f}) <<<")

        # 11. Incremental Saving 
        np.save('/kaggle/working/hasil_backup_mobilenetv3_partial_LR2.npy', {
            'hasil': hasil,
            'best_acc_per_optimizer': best_acc_per_optimizer,    
            'best_model_info_per_opt': best_model_info_per_opt, 
            'fold_terakhir': f"{nama_opt}_fold{fold+1}"
        })
        
        print(f"Backup disimpan! (progress aman sampai {nama_opt} Fold {fold+1})")

        # 12. Bersihkan memori setelah setiap fold
        del train_generator, val_generator         
        del y_train, y_val_true, y_pred_proba, y_pred
        del model
        gc.collect()
        tf.keras.backend.clear_session()

    waktu_opt = (time.time() - waktu_mulai_opt) / 60
    rata_acc = np.mean(hasil[nama_opt]['val_acc'])
    rata_f1  = np.mean(hasil[nama_opt]['val_macro_f1'])
    print(f"\n  {nama_opt} selesai! Rata-rata Acc: {rata_acc:.4f} | Macro F1: {rata_f1:.4f} ({waktu_opt:.1f} menit)")

#Menentukan optimizer terbaik berdasarkan rata-rata macro F1-Score
rata_acc_per_opt = {nama: np.mean(hasil[nama]['val_acc']) for nama in daftar_optimizer}
opt_terbaik = max(rata_acc_per_opt, key=rata_acc_per_opt.get)

print(f"\nOptimizer terbaik (rata-rata Accuracy): {opt_terbaik} ({rata_acc_per_opt[opt_terbaik]:.4f})")
print(f"Model tersimpan di: /kaggle/working/model_terbaik_mobilenetv3_partial_LR2{opt_terbaik}.keras")

waktu_total = (time.time() - waktu_mulai_total) / 60
info_opt = best_model_info_per_opt[opt_terbaik]
print(f"\n{'—'*55}")
print(f"  Training Sudah Selesai, dengan total waktu: {waktu_total:.1f} menit")
print(f"  Optimizer terbaik : {opt_terbaik} (rata-rata Accuracy: {rata_acc_per_opt[opt_terbaik]:.4f})")
print(f"  Fold terbaik      : Fold {info_opt['fold']}")
print(f"  Macro F1 (fold)   : {info_opt['val_macro_f1']:.4f}")
print(f"  Val Accuracy      : {info_opt['val_acc']:.4f}")
print(f"{'—'*55}")
# Out:
# Training Model
# ==================================================
#
# ———————————————————————————————————————————————————————
# OPTIMIZER: Adam
# ———————————————————————————————————————————————————————
#
#   --- Fold 1/5 (Adam) ---
#   Distribusi Training:
#     BCC: 1600
#     MEL: 1600
#     SCC: 502
#   Total Training: 3702 | Validation: 926
# Mulai training...
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780638503.712780      68 service.cc:152] XLA service 0x7eda8c0022c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1780638503.712822      68 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1780638505.137328      68 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1780638511.993263      68 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 67s 458ms/step - accuracy: 0.4654 - loss: 0.8586 - val_accuracy: 0.5875 - val_loss: 0.3869 - learning_rate: 1.0000e-04
# Epoch 2/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 308ms/step - accuracy: 0.5756 - loss: 0.5087 - val_accuracy: 0.6674 - val_loss: 0.3314 - learning_rate: 1.0000e-04
# Epoch 3/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 310ms/step - accuracy: 0.6337 - loss: 0.3821 - val_accuracy: 0.7009 - val_loss: 0.3113 - learning_rate: 1.0000e-04
# Epoch 4/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 307ms/step - accuracy: 0.6575 - loss: 0.3457 - val_accuracy: 0.6933 - val_loss: 0.2877 - learning_rate: 1.0000e-04
# Epoch 5/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.6669 - loss: 0.3186 - val_accuracy: 0.6825 - val_loss: 0.2810 - learning_rate: 1.0000e-04
# Epoch 6/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.6780 - loss: 0.2968 - val_accuracy: 0.7333 - val_loss: 0.2713 - learning_rate: 1.0000e-04
# Epoch 7/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.7050 - loss: 0.2819 - val_accuracy: 0.7192 - val_loss: 0.2670 - learning_rate: 1.0000e-04
# Epoch 8/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.7050 - loss: 0.2783 - val_accuracy: 0.6998 - val_loss: 0.2638 - learning_rate: 1.0000e-04
# Epoch 9/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 37s 315ms/step - accuracy: 0.7096 - loss: 0.2648 - val_accuracy: 0.7387 - val_loss: 0.2534 - learning_rate: 1.0000e-04
# Epoch 10/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 310ms/step - accuracy: 0.7253 - loss: 0.2566 - val_accuracy: 0.7505 - val_loss: 0.2513 - learning_rate: 1.0000e-04
# Epoch 11/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 300ms/step - accuracy: 0.7256 - loss: 0.2558 - val_accuracy: 0.7441 - val_loss: 0.2440 - learning_rate: 1.0000e-04
# Epoch 12/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.7328 - loss: 0.2413 - val_accuracy: 0.7376 - val_loss: 0.2422 - learning_rate: 1.0000e-04
# Epoch 13/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 306ms/step - accuracy: 0.7547 - loss: 0.2358 - val_accuracy: 0.7430 - val_loss: 0.2432 - learning_rate: 1.0000e-04
# Epoch 14/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.7539 - loss: 0.2304 - val_accuracy: 0.7538 - val_loss: 0.2367 - learning_rate: 1.0000e-04
# Epoch 15/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 300ms/step - accuracy: 0.7493 - loss: 0.2310 - val_accuracy: 0.7462 - val_loss: 0.2324 - learning_rate: 1.0000e-04
# Epoch 16/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 302ms/step - accuracy: 0.7550 - loss: 0.2252 - val_accuracy: 0.7721 - val_loss: 0.2356 - learning_rate: 1.0000e-04
# Epoch 17/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.7507 - loss: 0.2259 - val_accuracy: 0.7538 - val_loss: 0.2363 - learning_rate: 1.0000e-04
# Epoch 18/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.7717 - loss: 0.2172
# Epoch 18: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.7655 - loss: 0.2143 - val_accuracy: 0.7624 - val_loss: 0.2403 - learning_rate: 1.0000e-04
# Epoch 19/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 299ms/step - accuracy: 0.7807 - loss: 0.2078 - val_accuracy: 0.7581 - val_loss: 0.2299 - learning_rate: 5.0000e-05
# Epoch 20/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 310ms/step - accuracy: 0.7769 - loss: 0.2070 - val_accuracy: 0.7700 - val_loss: 0.2263 - learning_rate: 5.0000e-05
# Epoch 21/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 309ms/step - accuracy: 0.7777 - loss: 0.2008 - val_accuracy: 0.7657 - val_loss: 0.2211 - learning_rate: 5.0000e-05
# Epoch 22/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.7901 - loss: 0.1997 - val_accuracy: 0.7700 - val_loss: 0.2252 - learning_rate: 5.0000e-05
# Epoch 23/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 302ms/step - accuracy: 0.7880 - loss: 0.1988 - val_accuracy: 0.7700 - val_loss: 0.2179 - learning_rate: 5.0000e-05
# Epoch 24/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 37s 314ms/step - accuracy: 0.7850 - loss: 0.1936 - val_accuracy: 0.7667 - val_loss: 0.2201 - learning_rate: 5.0000e-05
# Epoch 25/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.8015 - loss: 0.1895 - val_accuracy: 0.7700 - val_loss: 0.2190 - learning_rate: 5.0000e-05
# Epoch 26/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.7832 - loss: 0.1894
# Epoch 26: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 302ms/step - accuracy: 0.7947 - loss: 0.1866 - val_accuracy: 0.7689 - val_loss: 0.2244 - learning_rate: 5.0000e-05
# Epoch 27/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 307ms/step - accuracy: 0.7961 - loss: 0.1933 - val_accuracy: 0.7667 - val_loss: 0.2206 - learning_rate: 2.5000e-05
# Epoch 28/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.7974 - loss: 0.1886 - val_accuracy: 0.7700 - val_loss: 0.2219 - learning_rate: 2.5000e-05
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 23.
#  Fold 1 selesai!
#   Val Accuracy : 0.7700
#   Val Macro F1 : 0.7265
# >>> Model Terbaik Baru untuk Adam (Accuracy=0.7700) <<<
# Backup disimpan! (progress aman sampai Adam Fold 1)
#
#   --- Fold 2/5 (Adam) ---
#   Distribusi Training:
#     BCC: 1600
#     MEL: 1600
#     SCC: 502
#   Total Training: 3702 | Validation: 926
# Mulai training...
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 58s 412ms/step - accuracy: 0.4387 - loss: 0.9513 - val_accuracy: 0.5853 - val_loss: 0.4053 - learning_rate: 1.0000e-04
# Epoch 2/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.5678 - loss: 0.5432 - val_accuracy: 0.6436 - val_loss: 0.3469 - learning_rate: 1.0000e-04
# Epoch 3/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.5967 - loss: 0.4370 - val_accuracy: 0.6652 - val_loss: 0.3244 - learning_rate: 1.0000e-04
# Epoch 4/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 308ms/step - accuracy: 0.6372 - loss: 0.3625 - val_accuracy: 0.7041 - val_loss: 0.3187 - learning_rate: 1.0000e-04
# Epoch 5/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.6667 - loss: 0.3203 - val_accuracy: 0.7073 - val_loss: 0.3119 - learning_rate: 1.0000e-04
# Epoch 6/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.6769 - loss: 0.3113 - val_accuracy: 0.7019 - val_loss: 0.2981 - learning_rate: 1.0000e-04
# Epoch 7/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.6837 - loss: 0.2940 - val_accuracy: 0.7203 - val_loss: 0.3032 - learning_rate: 1.0000e-04
# Epoch 8/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.6967 - loss: 0.2808 - val_accuracy: 0.7257 - val_loss: 0.2987 - learning_rate: 1.0000e-04
# Epoch 9/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.7201 - loss: 0.2713
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 307ms/step - accuracy: 0.7118 - loss: 0.2685 - val_accuracy: 0.7160 - val_loss: 0.3000 - learning_rate: 1.0000e-04
# Epoch 10/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.7188 - loss: 0.2644 - val_accuracy: 0.7300 - val_loss: 0.2988 - learning_rate: 5.0000e-05
# Epoch 11/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.7134 - loss: 0.2601 - val_accuracy: 0.7354 - val_loss: 0.2981 - learning_rate: 5.0000e-05
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 6.
#  Fold 2 selesai!
#   Val Accuracy : 0.7019
#   Val Macro F1 : 0.6537
# Backup disimpan! (progress aman sampai Adam Fold 2)
#
#   --- Fold 3/5 (Adam) ---
#   Distribusi Training:
#     BCC: 1600
#     MEL: 1600
#     SCC: 502
#   Total Training: 3702 | Validation: 926
# Mulai training...
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 58s 415ms/step - accuracy: 0.4392 - loss: 0.8458 - val_accuracy: 0.6307 - val_loss: 0.4107 - learning_rate: 1.0000e-04
# Epoch 2/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.5716 - loss: 0.4975 - val_accuracy: 0.6965 - val_loss: 0.3657 - learning_rate: 1.0000e-04
# Epoch 3/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 313ms/step - accuracy: 0.6337 - loss: 0.3939 - val_accuracy: 0.6987 - val_loss: 0.3221 - learning_rate: 1.0000e-04
# Epoch 4/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 37s 321ms/step - accuracy: 0.6432 - loss: 0.3526 - val_accuracy: 0.6793 - val_loss: 0.3189 - learning_rate: 1.0000e-04
# Epoch 5/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 308ms/step - accuracy: 0.6648 - loss: 0.3254 - val_accuracy: 0.6976 - val_loss: 0.3071 - learning_rate: 1.0000e-04
# Epoch 6/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.6804 - loss: 0.2983 - val_accuracy: 0.6760 - val_loss: 0.2938 - learning_rate: 1.0000e-04
# Epoch 7/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.6991 - loss: 0.2897 - val_accuracy: 0.6944 - val_loss: 0.2916 - learning_rate: 1.0000e-04
# Epoch 8/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.6921 - loss: 0.2839 - val_accuracy: 0.7343 - val_loss: 0.2851 - learning_rate: 1.0000e-04
# Epoch 9/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 310ms/step - accuracy: 0.7112 - loss: 0.2692 - val_accuracy: 0.7084 - val_loss: 0.2767 - learning_rate: 1.0000e-04
# Epoch 10/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 313ms/step - accuracy: 0.7166 - loss: 0.2593 - val_accuracy: 0.7257 - val_loss: 0.2734 - learning_rate: 1.0000e-04
# Epoch 11/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 300ms/step - accuracy: 0.7191 - loss: 0.2530 - val_accuracy: 0.7387 - val_loss: 0.2714 - learning_rate: 1.0000e-04
# Epoch 12/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.7347 - loss: 0.2463 - val_accuracy: 0.7484 - val_loss: 0.2712 - learning_rate: 1.0000e-04
# Epoch 13/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.7361 - loss: 0.2475 - val_accuracy: 0.7430 - val_loss: 0.2676 - learning_rate: 1.0000e-04
# Epoch 14/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.7442 - loss: 0.2358 - val_accuracy: 0.7300 - val_loss: 0.2672 - learning_rate: 1.0000e-04
# Epoch 15/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.7480 - loss: 0.2318 - val_accuracy: 0.7397 - val_loss: 0.2583 - learning_rate: 1.0000e-04
# Epoch 16/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.7501 - loss: 0.2269 - val_accuracy: 0.7473 - val_loss: 0.2493 - learning_rate: 1.0000e-04
# Epoch 17/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 310ms/step - accuracy: 0.7536 - loss: 0.2225 - val_accuracy: 0.7505 - val_loss: 0.2472 - learning_rate: 1.0000e-04
# Epoch 18/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.7642 - loss: 0.2188 - val_accuracy: 0.7430 - val_loss: 0.2512 - learning_rate: 1.0000e-04
# Epoch 19/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 302ms/step - accuracy: 0.7755 - loss: 0.2206 - val_accuracy: 0.7430 - val_loss: 0.2502 - learning_rate: 1.0000e-04
# Epoch 20/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 310ms/step - accuracy: 0.7680 - loss: 0.2091 - val_accuracy: 0.7441 - val_loss: 0.2470 - learning_rate: 1.0000e-04
# Epoch 21/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 306ms/step - accuracy: 0.7715 - loss: 0.2128 - val_accuracy: 0.7592 - val_loss: 0.2429 - learning_rate: 1.0000e-04
# Epoch 22/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.7790 - loss: 0.2060 - val_accuracy: 0.7700 - val_loss: 0.2401 - learning_rate: 1.0000e-04
# Epoch 23/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.7809 - loss: 0.2002 - val_accuracy: 0.7840 - val_loss: 0.2438 - learning_rate: 1.0000e-04
# Epoch 24/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.7871 - loss: 0.1981 - val_accuracy: 0.7711 - val_loss: 0.2325 - learning_rate: 1.0000e-04
# Epoch 25/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 307ms/step - accuracy: 0.7920 - loss: 0.1930 - val_accuracy: 0.7592 - val_loss: 0.2362 - learning_rate: 1.0000e-04
# Epoch 26/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 302ms/step - accuracy: 0.7869 - loss: 0.1866 - val_accuracy: 0.7689 - val_loss: 0.2344 - learning_rate: 1.0000e-04
# Epoch 27/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.8085 - loss: 0.1739
# Epoch 27: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.8055 - loss: 0.1751 - val_accuracy: 0.7732 - val_loss: 0.2333 - learning_rate: 1.0000e-04
# Epoch 28/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 306ms/step - accuracy: 0.7982 - loss: 0.1814 - val_accuracy: 0.7786 - val_loss: 0.2351 - learning_rate: 5.0000e-05
# Epoch 29/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.7998 - loss: 0.1834 - val_accuracy: 0.7786 - val_loss: 0.2358 - learning_rate: 5.0000e-05
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 24.
#  Fold 3 selesai!
#   Val Accuracy : 0.7711
#   Val Macro F1 : 0.7278
# >>> Model Terbaik Baru untuk Adam (Accuracy=0.7711) <<<
# Backup disimpan! (progress aman sampai Adam Fold 3)
#
#   --- Fold 4/5 (Adam) ---
#   Distribusi Training:
#     BCC: 1600
#     MEL: 1600
#     SCC: 503
#   Total Training: 3703 | Validation: 925
# Mulai training...
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 63s 453ms/step - accuracy: 0.4988 - loss: 0.7823 - val_accuracy: 0.6476 - val_loss: 0.4121 - learning_rate: 1.0000e-04
# Epoch 2/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.5695 - loss: 0.5321 - val_accuracy: 0.6735 - val_loss: 0.3699 - learning_rate: 1.0000e-04
# Epoch 3/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.6208 - loss: 0.4010 - val_accuracy: 0.6800 - val_loss: 0.3368 - learning_rate: 1.0000e-04
# Epoch 4/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 307ms/step - accuracy: 0.6462 - loss: 0.3553 - val_accuracy: 0.6908 - val_loss: 0.3118 - learning_rate: 1.0000e-04
# Epoch 5/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.6665 - loss: 0.3225 - val_accuracy: 0.6562 - val_loss: 0.3080 - learning_rate: 1.0000e-04
# Epoch 6/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.6851 - loss: 0.3037 - val_accuracy: 0.6649 - val_loss: 0.2975 - learning_rate: 1.0000e-04
# Epoch 7/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 307ms/step - accuracy: 0.6870 - loss: 0.2860 - val_accuracy: 0.7081 - val_loss: 0.2891 - learning_rate: 1.0000e-04
# Epoch 8/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.7194 - loss: 0.2668 - val_accuracy: 0.6832 - val_loss: 0.2782 - learning_rate: 1.0000e-04
# Epoch 9/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 307ms/step - accuracy: 0.7170 - loss: 0.2627 - val_accuracy: 0.6984 - val_loss: 0.2805 - learning_rate: 1.0000e-04
# Epoch 10/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 311ms/step - accuracy: 0.7321 - loss: 0.2570 - val_accuracy: 0.6995 - val_loss: 0.2749 - learning_rate: 1.0000e-04
# Epoch 11/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.7264 - loss: 0.2499 - val_accuracy: 0.7341 - val_loss: 0.2786 - learning_rate: 1.0000e-04
# Epoch 12/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.7351 - loss: 0.2478 - val_accuracy: 0.7265 - val_loss: 0.2661 - learning_rate: 1.0000e-04
# Epoch 13/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.7426 - loss: 0.2368 - val_accuracy: 0.7189 - val_loss: 0.2598 - learning_rate: 1.0000e-04
# Epoch 14/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.7580 - loss: 0.2311 - val_accuracy: 0.7124 - val_loss: 0.2541 - learning_rate: 1.0000e-04
# Epoch 15/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 301ms/step - accuracy: 0.7459 - loss: 0.2299 - val_accuracy: 0.7243 - val_loss: 0.2522 - learning_rate: 1.0000e-04
# Epoch 16/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 302ms/step - accuracy: 0.7505 - loss: 0.2327 - val_accuracy: 0.7449 - val_loss: 0.2549 - learning_rate: 1.0000e-04
# Epoch 17/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.7686 - loss: 0.2197 - val_accuracy: 0.7330 - val_loss: 0.2587 - learning_rate: 1.0000e-04
# Epoch 18/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.7650 - loss: 0.2157
# Epoch 18: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.7615 - loss: 0.2175 - val_accuracy: 0.7265 - val_loss: 0.2526 - learning_rate: 1.0000e-04
# Epoch 19/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 300ms/step - accuracy: 0.7699 - loss: 0.2074 - val_accuracy: 0.7232 - val_loss: 0.2520 - learning_rate: 5.0000e-05
# Epoch 20/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 300ms/step - accuracy: 0.7772 - loss: 0.2038 - val_accuracy: 0.7319 - val_loss: 0.2500 - learning_rate: 5.0000e-05
# Epoch 21/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 308ms/step - accuracy: 0.7899 - loss: 0.1983 - val_accuracy: 0.7286 - val_loss: 0.2508 - learning_rate: 5.0000e-05
# Epoch 22/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 300ms/step - accuracy: 0.7750 - loss: 0.2023 - val_accuracy: 0.7395 - val_loss: 0.2538 - learning_rate: 5.0000e-05
# Epoch 23/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.7813 - loss: 0.1936 - val_accuracy: 0.7341 - val_loss: 0.2462 - learning_rate: 5.0000e-05
# Epoch 24/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.7834 - loss: 0.1926 - val_accuracy: 0.7276 - val_loss: 0.2432 - learning_rate: 5.0000e-05
# Epoch 25/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.7840 - loss: 0.2068 - val_accuracy: 0.7373 - val_loss: 0.2398 - learning_rate: 5.0000e-05
# Epoch 26/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.8002 - loss: 0.1871 - val_accuracy: 0.7492 - val_loss: 0.2399 - learning_rate: 5.0000e-05
# Epoch 27/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.8023 - loss: 0.1902 - val_accuracy: 0.7459 - val_loss: 0.2375 - learning_rate: 5.0000e-05
# Epoch 28/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.8026 - loss: 0.1900 - val_accuracy: 0.7405 - val_loss: 0.2356 - learning_rate: 5.0000e-05
# Epoch 29/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.7980 - loss: 0.1892 - val_accuracy: 0.7395 - val_loss: 0.2354 - learning_rate: 5.0000e-05
# Epoch 30/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 301ms/step - accuracy: 0.7945 - loss: 0.1876 - val_accuracy: 0.7330 - val_loss: 0.2425 - learning_rate: 5.0000e-05
# Epoch 31/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 308ms/step - accuracy: 0.8061 - loss: 0.1837 - val_accuracy: 0.7459 - val_loss: 0.2332 - learning_rate: 5.0000e-05
# Epoch 32/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 310ms/step - accuracy: 0.8048 - loss: 0.1828 - val_accuracy: 0.7459 - val_loss: 0.2396 - learning_rate: 5.0000e-05
# Epoch 33/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.8031 - loss: 0.1776 - val_accuracy: 0.7362 - val_loss: 0.2415 - learning_rate: 5.0000e-05
# Epoch 34/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.8137 - loss: 0.1730
# Epoch 34: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 308ms/step - accuracy: 0.8075 - loss: 0.1802 - val_accuracy: 0.7514 - val_loss: 0.2345 - learning_rate: 5.0000e-05
# Epoch 35/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.8110 - loss: 0.1801 - val_accuracy: 0.7481 - val_loss: 0.2351 - learning_rate: 2.5000e-05
# Epoch 36/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.8139 - loss: 0.1730 - val_accuracy: 0.7492 - val_loss: 0.2360 - learning_rate: 2.5000e-05
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 31.
#  Fold 4 selesai!
#   Val Accuracy : 0.7459
#   Val Macro F1 : 0.6978
# Backup disimpan! (progress aman sampai Adam Fold 4)
#
#   --- Fold 5/5 (Adam) ---
#   Distribusi Training:
#     BCC: 1600
#     MEL: 1600
#     SCC: 503
#   Total Training: 3703 | Validation: 925
# Mulai training...
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 59s 416ms/step - accuracy: 0.4542 - loss: 0.8320 - val_accuracy: 0.6205 - val_loss: 0.3708 - learning_rate: 1.0000e-04
# Epoch 2/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.5893 - loss: 0.4625 - val_accuracy: 0.6703 - val_loss: 0.3213 - learning_rate: 1.0000e-04
# Epoch 3/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.6287 - loss: 0.3857 - val_accuracy: 0.7189 - val_loss: 0.3175 - learning_rate: 1.0000e-04
# Epoch 4/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.6333 - loss: 0.3654 - val_accuracy: 0.7200 - val_loss: 0.3007 - learning_rate: 1.0000e-04
# Epoch 5/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.6668 - loss: 0.3171 - val_accuracy: 0.7222 - val_loss: 0.2910 - learning_rate: 1.0000e-04
# Epoch 6/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 307ms/step - accuracy: 0.6684 - loss: 0.3101 - val_accuracy: 0.7178 - val_loss: 0.2827 - learning_rate: 1.0000e-04
# Epoch 7/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.6840 - loss: 0.2907 - val_accuracy: 0.7211 - val_loss: 0.2784 - learning_rate: 1.0000e-04
# Epoch 8/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.6984 - loss: 0.2828 - val_accuracy: 0.7449 - val_loss: 0.2742 - learning_rate: 1.0000e-04
# Epoch 9/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 311ms/step - accuracy: 0.7083 - loss: 0.2763 - val_accuracy: 0.7276 - val_loss: 0.2658 - learning_rate: 1.0000e-04
# Epoch 10/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 302ms/step - accuracy: 0.7170 - loss: 0.2650 - val_accuracy: 0.7351 - val_loss: 0.2714 - learning_rate: 1.0000e-04
# Epoch 11/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.7232 - loss: 0.2564 - val_accuracy: 0.7578 - val_loss: 0.2678 - learning_rate: 1.0000e-04
# Epoch 12/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 301ms/step - accuracy: 0.7340 - loss: 0.2494 - val_accuracy: 0.7524 - val_loss: 0.2641 - learning_rate: 1.0000e-04
# Epoch 13/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.7429 - loss: 0.2412 - val_accuracy: 0.7470 - val_loss: 0.2631 - learning_rate: 1.0000e-04
# Epoch 14/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 311ms/step - accuracy: 0.7502 - loss: 0.2360 - val_accuracy: 0.7503 - val_loss: 0.2560 - learning_rate: 1.0000e-04
# Epoch 15/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 302ms/step - accuracy: 0.7451 - loss: 0.2336 - val_accuracy: 0.7686 - val_loss: 0.2592 - learning_rate: 1.0000e-04
# Epoch 16/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 309ms/step - accuracy: 0.7553 - loss: 0.2290 - val_accuracy: 0.7730 - val_loss: 0.2456 - learning_rate: 1.0000e-04
# Epoch 17/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 310ms/step - accuracy: 0.7599 - loss: 0.2243 - val_accuracy: 0.7697 - val_loss: 0.2429 - learning_rate: 1.0000e-04
# Epoch 18/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 300ms/step - accuracy: 0.7443 - loss: 0.2216 - val_accuracy: 0.7686 - val_loss: 0.2398 - learning_rate: 1.0000e-04
# Epoch 19/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.7605 - loss: 0.2176 - val_accuracy: 0.7751 - val_loss: 0.2402 - learning_rate: 1.0000e-04
# Epoch 20/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.7723 - loss: 0.2099 - val_accuracy: 0.7773 - val_loss: 0.2379 - learning_rate: 1.0000e-04
# Epoch 21/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 307ms/step - accuracy: 0.7786 - loss: 0.2045 - val_accuracy: 0.7643 - val_loss: 0.2374 - learning_rate: 1.0000e-04
# Epoch 22/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.7726 - loss: 0.2075 - val_accuracy: 0.7838 - val_loss: 0.2377 - learning_rate: 1.0000e-04
# Epoch 23/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.7845 - loss: 0.1915 - val_accuracy: 0.7665 - val_loss: 0.2348 - learning_rate: 1.0000e-04
# Epoch 24/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 309ms/step - accuracy: 0.7753 - loss: 0.1964 - val_accuracy: 0.7892 - val_loss: 0.2401 - learning_rate: 1.0000e-04
# Epoch 25/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 310ms/step - accuracy: 0.7869 - loss: 0.1903 - val_accuracy: 0.7805 - val_loss: 0.2332 - learning_rate: 1.0000e-04
# Epoch 26/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 298ms/step - accuracy: 0.7929 - loss: 0.1881 - val_accuracy: 0.7978 - val_loss: 0.2404 - learning_rate: 1.0000e-04
# Epoch 27/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.7896 - loss: 0.1919 - val_accuracy: 0.7924 - val_loss: 0.2359 - learning_rate: 1.0000e-04
# Epoch 28/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.7967 - loss: 0.1894 - val_accuracy: 0.7838 - val_loss: 0.2261 - learning_rate: 1.0000e-04
# Epoch 29/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.8026 - loss: 0.1787 - val_accuracy: 0.7935 - val_loss: 0.2432 - learning_rate: 1.0000e-04
# Epoch 30/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 302ms/step - accuracy: 0.8048 - loss: 0.1766 - val_accuracy: 0.7935 - val_loss: 0.2292 - learning_rate: 1.0000e-04
# Epoch 31/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.8130 - loss: 0.1709
# Epoch 31: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 301ms/step - accuracy: 0.8023 - loss: 0.1773 - val_accuracy: 0.7903 - val_loss: 0.2408 - learning_rate: 1.0000e-04
# Epoch 32/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 299ms/step - accuracy: 0.8126 - loss: 0.1747 - val_accuracy: 0.7935 - val_loss: 0.2278 - learning_rate: 5.0000e-05
# Epoch 33/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 307ms/step - accuracy: 0.8107 - loss: 0.1680 - val_accuracy: 0.8022 - val_loss: 0.2267 - learning_rate: 5.0000e-05
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 28.
#  Fold 5 selesai!
#   Val Accuracy : 0.7838
#   Val Macro F1 : 0.7341
# >>> Model Terbaik Baru untuk Adam (Accuracy=0.7838) <<<
# Backup disimpan! (progress aman sampai Adam Fold 5)
#
#   Adam selesai! Rata-rata Acc: 0.7545 | Macro F1: 0.7080 (84.2 menit)
#
# ———————————————————————————————————————————————————————
# OPTIMIZER: RMSprop
# ———————————————————————————————————————————————————————
#
#   --- Fold 1/5 (RMSprop) ---
#   Distribusi Training:
#     BCC: 1600
#     MEL: 1600
#     SCC: 502
#   Total Training: 3702 | Validation: 926
# Mulai training...
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 58s 411ms/step - accuracy: 0.4895 - loss: 0.8100 - val_accuracy: 0.6922 - val_loss: 0.3967 - learning_rate: 1.0000e-04
# Epoch 2/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 307ms/step - accuracy: 0.5983 - loss: 0.5113 - val_accuracy: 0.7214 - val_loss: 0.3343 - learning_rate: 1.0000e-04
# Epoch 3/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.6375 - loss: 0.3888 - val_accuracy: 0.7311 - val_loss: 0.3312 - learning_rate: 1.0000e-04
# Epoch 4/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.6507 - loss: 0.3397 - val_accuracy: 0.7279 - val_loss: 0.3018 - learning_rate: 1.0000e-04
# Epoch 5/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.6815 - loss: 0.3176 - val_accuracy: 0.7516 - val_loss: 0.2953 - learning_rate: 1.0000e-04
# Epoch 6/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.6977 - loss: 0.2956 - val_accuracy: 0.7581 - val_loss: 0.2820 - learning_rate: 1.0000e-04
# Epoch 7/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.7172 - loss: 0.2737 - val_accuracy: 0.7603 - val_loss: 0.2693 - learning_rate: 1.0000e-04
# Epoch 8/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.7145 - loss: 0.2809 - val_accuracy: 0.7387 - val_loss: 0.2573 - learning_rate: 1.0000e-04
# Epoch 9/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 310ms/step - accuracy: 0.7220 - loss: 0.2728 - val_accuracy: 0.7311 - val_loss: 0.2621 - learning_rate: 1.0000e-04
# Epoch 10/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.7323 - loss: 0.2616 - val_accuracy: 0.7549 - val_loss: 0.2722 - learning_rate: 1.0000e-04
# Epoch 11/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.7275 - loss: 0.2602
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.7407 - loss: 0.2458 - val_accuracy: 0.7570 - val_loss: 0.2641 - learning_rate: 1.0000e-04
# Epoch 12/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 34s 297ms/step - accuracy: 0.7496 - loss: 0.2381 - val_accuracy: 0.7581 - val_loss: 0.2582 - learning_rate: 5.0000e-05
# Epoch 13/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.7485 - loss: 0.2420 - val_accuracy: 0.7538 - val_loss: 0.2485 - learning_rate: 5.0000e-05
# Epoch 14/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.7569 - loss: 0.2324 - val_accuracy: 0.7559 - val_loss: 0.2506 - learning_rate: 5.0000e-05
# Epoch 15/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 298ms/step - accuracy: 0.7590 - loss: 0.2367 - val_accuracy: 0.7613 - val_loss: 0.2517 - learning_rate: 5.0000e-05
# Epoch 16/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.7542 - loss: 0.2331 - val_accuracy: 0.7581 - val_loss: 0.2467 - learning_rate: 5.0000e-05
# Epoch 17/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.7574 - loss: 0.2276 - val_accuracy: 0.7581 - val_loss: 0.2480 - learning_rate: 5.0000e-05
# Epoch 18/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.7615 - loss: 0.2303 - val_accuracy: 0.7592 - val_loss: 0.2445 - learning_rate: 5.0000e-05
# Epoch 19/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.7645 - loss: 0.2242 - val_accuracy: 0.7646 - val_loss: 0.2459 - learning_rate: 5.0000e-05
# Epoch 20/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 37s 317ms/step - accuracy: 0.7618 - loss: 0.2210 - val_accuracy: 0.7646 - val_loss: 0.2421 - learning_rate: 5.0000e-05
# Epoch 21/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.7761 - loss: 0.2232 - val_accuracy: 0.7613 - val_loss: 0.2430 - learning_rate: 5.0000e-05
# Epoch 22/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.7753 - loss: 0.2173 - val_accuracy: 0.7603 - val_loss: 0.2448 - learning_rate: 5.0000e-05
# Epoch 23/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 309ms/step - accuracy: 0.7666 - loss: 0.2157 - val_accuracy: 0.7689 - val_loss: 0.2390 - learning_rate: 5.0000e-05
# Epoch 24/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.7666 - loss: 0.2169 - val_accuracy: 0.7689 - val_loss: 0.2449 - learning_rate: 5.0000e-05
# Epoch 25/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 307ms/step - accuracy: 0.7682 - loss: 0.2173 - val_accuracy: 0.7711 - val_loss: 0.2419 - learning_rate: 5.0000e-05
# Epoch 26/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.7526 - loss: 0.2195
# Epoch 26: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 310ms/step - accuracy: 0.7677 - loss: 0.2148 - val_accuracy: 0.7646 - val_loss: 0.2393 - learning_rate: 5.0000e-05
# Epoch 27/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 309ms/step - accuracy: 0.7661 - loss: 0.2083 - val_accuracy: 0.7711 - val_loss: 0.2341 - learning_rate: 2.5000e-05
# Epoch 28/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.7853 - loss: 0.2016 - val_accuracy: 0.7700 - val_loss: 0.2353 - learning_rate: 2.5000e-05
# Epoch 29/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.7847 - loss: 0.2059 - val_accuracy: 0.7732 - val_loss: 0.2353 - learning_rate: 2.5000e-05
# Epoch 30/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.7887 - loss: 0.1986
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 306ms/step - accuracy: 0.7880 - loss: 0.2030 - val_accuracy: 0.7711 - val_loss: 0.2388 - learning_rate: 2.5000e-05
# Epoch 31/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 308ms/step - accuracy: 0.7858 - loss: 0.2068 - val_accuracy: 0.7721 - val_loss: 0.2368 - learning_rate: 1.2500e-05
# Epoch 32/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 300ms/step - accuracy: 0.7812 - loss: 0.2048 - val_accuracy: 0.7711 - val_loss: 0.2368 - learning_rate: 1.2500e-05
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 27.
#  Fold 1 selesai!
#   Val Accuracy : 0.7711
#   Val Macro F1 : 0.7264
# >>> Model Terbaik Baru untuk RMSprop (Accuracy=0.7711) <<<
# Backup disimpan! (progress aman sampai RMSprop Fold 1)
#
#   --- Fold 2/5 (RMSprop) ---
#   Distribusi Training:
#     BCC: 1600
#     MEL: 1600
#     SCC: 502
#   Total Training: 3702 | Validation: 926
# Mulai training...
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 59s 416ms/step - accuracy: 0.4800 - loss: 0.8115 - val_accuracy: 0.5745 - val_loss: 0.3915 - learning_rate: 1.0000e-04
# Epoch 2/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.5870 - loss: 0.5164 - val_accuracy: 0.6890 - val_loss: 0.3886 - learning_rate: 1.0000e-04
# Epoch 3/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 308ms/step - accuracy: 0.6321 - loss: 0.4248 - val_accuracy: 0.6857 - val_loss: 0.3351 - learning_rate: 1.0000e-04
# Epoch 4/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.6569 - loss: 0.3525 - val_accuracy: 0.6911 - val_loss: 0.3407 - learning_rate: 1.0000e-04
# Epoch 5/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 307ms/step - accuracy: 0.6807 - loss: 0.3139 - val_accuracy: 0.7192 - val_loss: 0.3332 - learning_rate: 1.0000e-04
# Epoch 6/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 307ms/step - accuracy: 0.6885 - loss: 0.3069 - val_accuracy: 0.7203 - val_loss: 0.3161 - learning_rate: 1.0000e-04
# Epoch 7/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 301ms/step - accuracy: 0.6885 - loss: 0.2945 - val_accuracy: 0.7300 - val_loss: 0.3382 - learning_rate: 1.0000e-04
# Epoch 8/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.7075 - loss: 0.2721 - val_accuracy: 0.7408 - val_loss: 0.3332 - learning_rate: 1.0000e-04
# Epoch 9/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 309ms/step - accuracy: 0.7234 - loss: 0.2710 - val_accuracy: 0.7138 - val_loss: 0.3131 - learning_rate: 1.0000e-04
# Epoch 10/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.7204 - loss: 0.2681 - val_accuracy: 0.7333 - val_loss: 0.3047 - learning_rate: 1.0000e-04
# Epoch 11/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.7326 - loss: 0.2540 - val_accuracy: 0.7387 - val_loss: 0.3293 - learning_rate: 1.0000e-04
# Epoch 12/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.7326 - loss: 0.2501 - val_accuracy: 0.7430 - val_loss: 0.3331 - learning_rate: 1.0000e-04
# Epoch 13/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.7460 - loss: 0.2361
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 302ms/step - accuracy: 0.7485 - loss: 0.2452 - val_accuracy: 0.7397 - val_loss: 0.3101 - learning_rate: 1.0000e-04
# Epoch 14/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.7420 - loss: 0.2437 - val_accuracy: 0.7570 - val_loss: 0.3257 - learning_rate: 5.0000e-05
# Epoch 15/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 302ms/step - accuracy: 0.7620 - loss: 0.2336 - val_accuracy: 0.7538 - val_loss: 0.3193 - learning_rate: 5.0000e-05
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 10.
#  Fold 2 selesai!
#   Val Accuracy : 0.7333
#   Val Macro F1 : 0.6768
# Backup disimpan! (progress aman sampai RMSprop Fold 2)
#
#   --- Fold 3/5 (RMSprop) ---
#   Distribusi Training:
#     BCC: 1600
#     MEL: 1600
#     SCC: 502
#   Total Training: 3702 | Validation: 926
# Mulai training...
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 59s 417ms/step - accuracy: 0.4851 - loss: 0.8161 - val_accuracy: 0.6533 - val_loss: 0.3758 - learning_rate: 1.0000e-04
# Epoch 2/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.5786 - loss: 0.5181 - val_accuracy: 0.6620 - val_loss: 0.3490 - learning_rate: 1.0000e-04
# Epoch 3/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 307ms/step - accuracy: 0.6216 - loss: 0.3975 - val_accuracy: 0.6965 - val_loss: 0.3013 - learning_rate: 1.0000e-04
# Epoch 4/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.6453 - loss: 0.3569 - val_accuracy: 0.7106 - val_loss: 0.3048 - learning_rate: 1.0000e-04
# Epoch 5/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 308ms/step - accuracy: 0.6737 - loss: 0.3182 - val_accuracy: 0.7117 - val_loss: 0.2960 - learning_rate: 1.0000e-04
# Epoch 6/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.6910 - loss: 0.3113 - val_accuracy: 0.7354 - val_loss: 0.2912 - learning_rate: 1.0000e-04
# Epoch 7/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 302ms/step - accuracy: 0.6923 - loss: 0.2934 - val_accuracy: 0.7138 - val_loss: 0.2984 - learning_rate: 1.0000e-04
# Epoch 8/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.7061 - loss: 0.2811 - val_accuracy: 0.7235 - val_loss: 0.2870 - learning_rate: 1.0000e-04
# Epoch 9/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 308ms/step - accuracy: 0.6980 - loss: 0.2802 - val_accuracy: 0.7365 - val_loss: 0.2943 - learning_rate: 1.0000e-04
# Epoch 10/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 308ms/step - accuracy: 0.7237 - loss: 0.2640 - val_accuracy: 0.7311 - val_loss: 0.2851 - learning_rate: 1.0000e-04
# Epoch 11/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 302ms/step - accuracy: 0.7237 - loss: 0.2633 - val_accuracy: 0.7279 - val_loss: 0.2796 - learning_rate: 1.0000e-04
# Epoch 12/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 302ms/step - accuracy: 0.7353 - loss: 0.2558 - val_accuracy: 0.7225 - val_loss: 0.2835 - learning_rate: 1.0000e-04
# Epoch 13/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.7334 - loss: 0.2557 - val_accuracy: 0.7387 - val_loss: 0.2705 - learning_rate: 1.0000e-04
# Epoch 14/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.7464 - loss: 0.2439 - val_accuracy: 0.7354 - val_loss: 0.2707 - learning_rate: 1.0000e-04
# Epoch 15/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.7434 - loss: 0.2449 - val_accuracy: 0.7624 - val_loss: 0.2681 - learning_rate: 1.0000e-04
# Epoch 16/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 307ms/step - accuracy: 0.7428 - loss: 0.2368 - val_accuracy: 0.7581 - val_loss: 0.2764 - learning_rate: 1.0000e-04
# Epoch 17/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.7488 - loss: 0.2320 - val_accuracy: 0.7559 - val_loss: 0.2642 - learning_rate: 1.0000e-04
# Epoch 18/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.7650 - loss: 0.2288 - val_accuracy: 0.7570 - val_loss: 0.2580 - learning_rate: 1.0000e-04
# Epoch 19/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 299ms/step - accuracy: 0.7699 - loss: 0.2243 - val_accuracy: 0.7559 - val_loss: 0.2630 - learning_rate: 1.0000e-04
# Epoch 20/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 308ms/step - accuracy: 0.7750 - loss: 0.2139 - val_accuracy: 0.7505 - val_loss: 0.2781 - learning_rate: 1.0000e-04
# Epoch 21/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.7775 - loss: 0.2152
# Epoch 21: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 301ms/step - accuracy: 0.7750 - loss: 0.2135 - val_accuracy: 0.7570 - val_loss: 0.2603 - learning_rate: 1.0000e-04
# Epoch 22/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.7704 - loss: 0.2091 - val_accuracy: 0.7613 - val_loss: 0.2718 - learning_rate: 5.0000e-05
# Epoch 23/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 307ms/step - accuracy: 0.7793 - loss: 0.2059 - val_accuracy: 0.7603 - val_loss: 0.2661 - learning_rate: 5.0000e-05
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 18.
#  Fold 3 selesai!
#   Val Accuracy : 0.7570
#   Val Macro F1 : 0.6959
# Backup disimpan! (progress aman sampai RMSprop Fold 3)
#
#   --- Fold 4/5 (RMSprop) ---
#   Distribusi Training:
#     BCC: 1600
#     MEL: 1600
#     SCC: 503
#   Total Training: 3703 | Validation: 925
# Mulai training...
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 58s 412ms/step - accuracy: 0.4672 - loss: 0.8567 - val_accuracy: 0.6541 - val_loss: 0.4140 - learning_rate: 1.0000e-04
# Epoch 2/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.5960 - loss: 0.4842 - val_accuracy: 0.6659 - val_loss: 0.3585 - learning_rate: 1.0000e-04
# Epoch 3/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.6327 - loss: 0.4050 - val_accuracy: 0.6854 - val_loss: 0.3361 - learning_rate: 1.0000e-04
# Epoch 4/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.6614 - loss: 0.3457 - val_accuracy: 0.7081 - val_loss: 0.3271 - learning_rate: 1.0000e-04
# Epoch 5/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.6854 - loss: 0.3088 - val_accuracy: 0.7254 - val_loss: 0.3196 - learning_rate: 1.0000e-04
# Epoch 6/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 302ms/step - accuracy: 0.6938 - loss: 0.2929 - val_accuracy: 0.7168 - val_loss: 0.2927 - learning_rate: 1.0000e-04
# Epoch 7/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 307ms/step - accuracy: 0.7067 - loss: 0.2848 - val_accuracy: 0.7092 - val_loss: 0.2852 - learning_rate: 1.0000e-04
# Epoch 8/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.7065 - loss: 0.2758 - val_accuracy: 0.7341 - val_loss: 0.2856 - learning_rate: 1.0000e-04
# Epoch 9/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 310ms/step - accuracy: 0.7308 - loss: 0.2629 - val_accuracy: 0.7286 - val_loss: 0.2791 - learning_rate: 1.0000e-04
# Epoch 10/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.7329 - loss: 0.2603 - val_accuracy: 0.7330 - val_loss: 0.2838 - learning_rate: 1.0000e-04
# Epoch 11/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 298ms/step - accuracy: 0.7329 - loss: 0.2538 - val_accuracy: 0.7524 - val_loss: 0.2800 - learning_rate: 1.0000e-04
# Epoch 12/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.7558 - loss: 0.2341
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 302ms/step - accuracy: 0.7470 - loss: 0.2415 - val_accuracy: 0.7589 - val_loss: 0.3024 - learning_rate: 1.0000e-04
# Epoch 13/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.7408 - loss: 0.2442 - val_accuracy: 0.7524 - val_loss: 0.2849 - learning_rate: 5.0000e-05
# Epoch 14/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.7537 - loss: 0.2360 - val_accuracy: 0.7319 - val_loss: 0.2733 - learning_rate: 5.0000e-05
# Epoch 15/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 301ms/step - accuracy: 0.7548 - loss: 0.2308 - val_accuracy: 0.7427 - val_loss: 0.2857 - learning_rate: 5.0000e-05
# Epoch 16/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.7607 - loss: 0.2267 - val_accuracy: 0.7459 - val_loss: 0.2943 - learning_rate: 5.0000e-05
# Epoch 17/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.7688 - loss: 0.2242
# Epoch 17: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 308ms/step - accuracy: 0.7637 - loss: 0.2306 - val_accuracy: 0.7362 - val_loss: 0.2746 - learning_rate: 5.0000e-05
# Epoch 18/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 307ms/step - accuracy: 0.7556 - loss: 0.2273 - val_accuracy: 0.7535 - val_loss: 0.2831 - learning_rate: 2.5000e-05
# Epoch 19/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.7602 - loss: 0.2246 - val_accuracy: 0.7416 - val_loss: 0.2812 - learning_rate: 2.5000e-05
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 14.
#  Fold 4 selesai!
#   Val Accuracy : 0.7319
#   Val Macro F1 : 0.6811
# Backup disimpan! (progress aman sampai RMSprop Fold 4)
#
#   --- Fold 5/5 (RMSprop) ---
#   Distribusi Training:
#     BCC: 1600
#     MEL: 1600
#     SCC: 503
#   Total Training: 3703 | Validation: 925
# Mulai training...
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 58s 411ms/step - accuracy: 0.4815 - loss: 0.7972 - val_accuracy: 0.6076 - val_loss: 0.3770 - learning_rate: 1.0000e-04
# Epoch 2/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.5976 - loss: 0.5089 - val_accuracy: 0.6357 - val_loss: 0.3399 - learning_rate: 1.0000e-04
# Epoch 3/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.6203 - loss: 0.4009 - val_accuracy: 0.6757 - val_loss: 0.3277 - learning_rate: 1.0000e-04
# Epoch 4/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 301ms/step - accuracy: 0.6535 - loss: 0.3467 - val_accuracy: 0.6551 - val_loss: 0.3098 - learning_rate: 1.0000e-04
# Epoch 5/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.6781 - loss: 0.3081 - val_accuracy: 0.6465 - val_loss: 0.3050 - learning_rate: 1.0000e-04
# Epoch 6/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.6919 - loss: 0.2975 - val_accuracy: 0.7146 - val_loss: 0.2860 - learning_rate: 1.0000e-04
# Epoch 7/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.6970 - loss: 0.2874 - val_accuracy: 0.7135 - val_loss: 0.2790 - learning_rate: 1.0000e-04
# Epoch 8/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.7089 - loss: 0.2804 - val_accuracy: 0.7027 - val_loss: 0.2752 - learning_rate: 1.0000e-04
# Epoch 9/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 310ms/step - accuracy: 0.7235 - loss: 0.2691 - val_accuracy: 0.7254 - val_loss: 0.2736 - learning_rate: 1.0000e-04
# Epoch 10/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.7240 - loss: 0.2573 - val_accuracy: 0.7265 - val_loss: 0.2766 - learning_rate: 1.0000e-04
# Epoch 11/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 306ms/step - accuracy: 0.7370 - loss: 0.2567 - val_accuracy: 0.7070 - val_loss: 0.2687 - learning_rate: 1.0000e-04
# Epoch 12/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 301ms/step - accuracy: 0.7340 - loss: 0.2432 - val_accuracy: 0.7405 - val_loss: 0.2719 - learning_rate: 1.0000e-04
# Epoch 13/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.7381 - loss: 0.2465 - val_accuracy: 0.7265 - val_loss: 0.2698 - learning_rate: 1.0000e-04
# Epoch 14/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.7513 - loss: 0.2382 - val_accuracy: 0.7514 - val_loss: 0.2662 - learning_rate: 1.0000e-04
# Epoch 15/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 301ms/step - accuracy: 0.7459 - loss: 0.2370 - val_accuracy: 0.7395 - val_loss: 0.2637 - learning_rate: 1.0000e-04
# Epoch 16/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 307ms/step - accuracy: 0.7543 - loss: 0.2270 - val_accuracy: 0.7341 - val_loss: 0.2615 - learning_rate: 1.0000e-04
# Epoch 17/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 310ms/step - accuracy: 0.7615 - loss: 0.2203 - val_accuracy: 0.7503 - val_loss: 0.2691 - learning_rate: 1.0000e-04
# Epoch 18/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 307ms/step - accuracy: 0.7586 - loss: 0.2257 - val_accuracy: 0.7384 - val_loss: 0.2577 - learning_rate: 1.0000e-04
# Epoch 19/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 302ms/step - accuracy: 0.7567 - loss: 0.2238 - val_accuracy: 0.7384 - val_loss: 0.2598 - learning_rate: 1.0000e-04
# Epoch 20/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 305ms/step - accuracy: 0.7686 - loss: 0.2164 - val_accuracy: 0.7405 - val_loss: 0.2638 - learning_rate: 1.0000e-04
# Epoch 21/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.7627 - loss: 0.2179
# Epoch 21: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 306ms/step - accuracy: 0.7667 - loss: 0.2151 - val_accuracy: 0.7459 - val_loss: 0.2623 - learning_rate: 1.0000e-04
# Epoch 22/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 300ms/step - accuracy: 0.7737 - loss: 0.2034 - val_accuracy: 0.7622 - val_loss: 0.2604 - learning_rate: 5.0000e-05
# Epoch 23/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 35s 303ms/step - accuracy: 0.7858 - loss: 0.2068 - val_accuracy: 0.7568 - val_loss: 0.2579 - learning_rate: 5.0000e-05
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 18.
#  Fold 5 selesai!
#   Val Accuracy : 0.7384
#   Val Macro F1 : 0.6967
# Backup disimpan! (progress aman sampai RMSprop Fold 5)
#
#   RMSprop selesai! Rata-rata Acc: 0.7463 | Macro F1: 0.6954 (69.2 menit)
#
# Optimizer terbaik (rata-rata Accuracy): Adam (0.7545)
# Model tersimpan di: /kaggle/working/model_terbaik_mobilenetv3_partial_LR2Adam.keras
#
# ———————————————————————————————————————————————————————
#   Training Sudah Selesai, dengan total waktu: 153.4 menit
#   Optimizer terbaik : Adam (rata-rata Accuracy: 0.7545)
#   Fold terbaik      : Fold 5
#   Macro F1 (fold)   : 0.7341
#   Val Accuracy      : 0.7838
# ———————————————————————————————————————————————————————

# %% [markdown]
# <div style="
#     padding-left: 18px;
#     border-left: 4px solid #111827;
#     margin-top: 25px;
# ">
#
# <h3 style="
#     margin-bottom: 8px;
#     font-size: 24px;
#     font-weight: 600;
# "> Tahap 7 - Perbandingan Dan Evaluasi
# </h3>
#
# <p style="
#     margin-top: 0;
#     color: #555;
#     line-height: 1.7;
# "> Perbandingan akan dilihat per optimizer, mana yang paling bagus.</p>
#
# </div>

# %%
print("Hasil Perbandingan Optimizer")
print("=" * 50)

# Key history
ACC_KEY     = 'accuracy'
VAL_ACC_KEY = 'val_accuracy'

def hitung_macro_metrics(y_true, y_pred, num_classes):
    cm = confusion_matrix(y_true, y_pred, labels=range(num_classes))
    acc = accuracy_score(y_true, y_pred)

    prec_list, rec_list, f1_list = [], [], []
    for k in range(num_classes):
        TP = cm[k, k]
        FP = cm[:, k].sum() - TP
        FN = cm[k, :].sum() - TP
        prec = TP / (TP + FP) if (TP + FP) > 0 else 0
        rec  = TP / (TP + FN) if (TP + FN) > 0 else 0
        f1   = 2 * prec * rec / (prec + rec) if (prec + rec) > 0 else 0
        prec_list.append(prec)
        rec_list.append(rec)
        f1_list.append(f1)

    return acc, float(np.mean(prec_list)), float(np.mean(rec_list)), float(np.mean(f1_list))

print("\nTabel Perbandingan Acc, Prec, Rec, dan Macro F1 per Fold:")
print("—" * 100)

metrics_per_opt = {
    nama_opt: {'acc': [], 'prec': [], 'rec': [], 'f1': []}
    for nama_opt in daftar_optimizer
}

for nama_opt in daftar_optimizer:
    for fold in range(N_FOLDS):
        y_true_f = np.array(hasil[nama_opt]['y_true_fold'][fold])
        y_pred_f = np.array(hasil[nama_opt]['y_pred_fold'][fold])
        acc, macro_prec, macro_rec, macro_f1 = hitung_macro_metrics(
            y_true_f, y_pred_f, NUM_CLASSES
        )
        metrics_per_opt[nama_opt]['acc'].append(acc)
        metrics_per_opt[nama_opt]['prec'].append(macro_prec)
        metrics_per_opt[nama_opt]['rec'].append(macro_rec)
        metrics_per_opt[nama_opt]['f1'].append(macro_f1)

header = f"  {'Fold':<8}" + "".join(
    f"{n+' Acc':<12}{n+' Prec':<12}{n+' Rec':<12}{n+' F1':<12}"
    for n in daftar_optimizer
    )
print(header)
print("  " + "—" * 95)

for fold in range(N_FOLDS):
    baris = f"  Fold {fold+1:<3}"
    for nama_opt in daftar_optimizer:
        baris += f"{metrics_per_opt[nama_opt]['acc'][fold]:<12.4f}"
        baris += f"{metrics_per_opt[nama_opt]['prec'][fold]:<12.4f}"
        baris += f"{metrics_per_opt[nama_opt]['rec'][fold]:<12.4f}"
        baris += f"{metrics_per_opt[nama_opt]['f1'][fold]:<12.4f}"
    print(baris)
print("  " + "—" * 95)

baris_rata = f"  {'Rata':<8}"
for nama_opt in daftar_optimizer:
    baris_rata += f"{np.mean(metrics_per_opt[nama_opt]['acc']):<12.4f}"
    baris_rata += f"{np.mean(metrics_per_opt[nama_opt]['prec']):<12.4f}"
    baris_rata += f"{np.mean(metrics_per_opt[nama_opt]['rec']):<12.4f}"
    baris_rata += f"{np.mean(metrics_per_opt[nama_opt]['f1']):<12.4f}"
print(baris_rata)

# opt_terbaik dan rata_f1_per_opt sudah didefinisikan di cell training (cell 19)
print(f"\nOptimizer terbaik (rata-rata Accuracy): {opt_terbaik} ({rata_acc_per_opt[opt_terbaik]:.4f})")

      
# Helper
def pad_nan(lst, length):
    return lst + [np.nan] * (length - len(lst))


# Grafik 1 : Rata-rata Validation dan Loss 5-Fold
for nama_opt in daftar_optimizer:
    histories  = hasil[nama_opt]['history']
    max_epochs = max(len(h[ACC_KEY]) for h in histories)
    epochs     = np.arange(1, max_epochs + 1)

    mat_train_acc  = np.array([pad_nan(h[ACC_KEY],     max_epochs) for h in histories])
    mat_val_acc    = np.array([pad_nan(h[VAL_ACC_KEY], max_epochs) for h in histories])
    mat_train_loss = np.array([pad_nan(h['loss'],      max_epochs) for h in histories])
    mat_val_loss   = np.array([pad_nan(h['val_loss'],  max_epochs) for h in histories])

    mean_train_acc  = np.nanmean(mat_train_acc,  axis=0)
    mean_val_acc    = np.nanmean(mat_val_acc,    axis=0)
    mean_train_loss = np.nanmean(mat_train_loss, axis=0)
    mean_val_loss   = np.nanmean(mat_val_loss,   axis=0)

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    fig.suptitle(f'Rata-rata 5-Fold: Train dan Validation — {nama_opt}',
                 fontsize=13, fontweight='bold')

    # Accuracy
    ax = axes[0]
    ax.plot(epochs, mean_train_acc, color='#2980b9', lw=2,
            marker='o', markersize=4, label='Train Accuracy')
    ax.plot(epochs, mean_val_acc,   color='#c0392b', lw=2,
            marker='o', markersize=4, label='Validation Accuracy')
    ax.axhline(0.7, color='gray', ls='--', alpha=0.5, label='Target 70%')
    ax.set_title('Accuracy', fontweight='bold')
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Accuracy')
    ax.legend()
    ax.grid(True, alpha=0.3)

    # Loss
    ax = axes[1]
    ax.plot(epochs, mean_train_loss, color='#2980b9', lw=2,
            marker='o', markersize=4, label='Train Loss')
    ax.plot(epochs, mean_val_loss,   color='#c0392b', lw=2,
            marker='o', markersize=4, label='Validation Loss')
    ax.set_title('Loss', fontweight='bold')
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Loss')
    ax.legend()
    ax.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(f'avg_train_val_{nama_opt}.png', dpi=150, bbox_inches='tight')
    plt.show()


# Grafik 2 : Training Curve per Fold 
for nama_opt in daftar_optimizer:
    histories = hasil[nama_opt]['history']

    fig, axes = plt.subplots(N_FOLDS, 2, figsize=(14, 4 * N_FOLDS))
    fig.suptitle(f'Training Curve per Fold — {nama_opt}',
                 fontsize=14, fontweight='bold')

    for fold in range(N_FOLDS):
        h      = histories[fold]
        epochs = range(1, len(h['loss']) + 1)

        ax_loss = axes[fold, 0]
        ax_acc  = axes[fold, 1]

        ax_loss.plot(epochs, h['loss'],     color='#2980b9', lw=1.8, label='Train Loss')
        ax_loss.plot(epochs, h['val_loss'], color='#e67e22', lw=1.8, label='Val Loss')
        ax_loss.set_title(f'Fold {fold+1} — Loss', fontweight='bold')
        ax_loss.set_xlabel('Epoch')
        ax_loss.set_ylabel('Loss')
        ax_loss.legend(fontsize=9)
        ax_loss.grid(True, alpha=0.3)

        ax_acc.plot(epochs, h[ACC_KEY],     color='#27ae60', lw=1.8, label='Train Acc')
        ax_acc.plot(epochs, h[VAL_ACC_KEY], color='#c0392b', lw=1.8, label='Val Acc')
        ax_acc.axhline(0.7, color='gray', ls='--', alpha=0.5, label='Target 70%')
        ax_acc.set_title(f'Fold {fold+1} — Accuracy', fontweight='bold')
        ax_acc.set_xlabel('Epoch')
        ax_acc.set_ylabel('Accuracy')
        ax_acc.legend(fontsize=9)
        ax_acc.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(f'training_curve_perfold_{nama_opt}.png', dpi=150, bbox_inches='tight')
    plt.show()
# Out:
# Hasil Perbandingan Optimizer
# ==================================================
#
# Tabel Perbandingan Acc, Prec, Rec, dan Macro F1 per Fold:
# ————————————————————————————————————————————————————————————————————————————————————————————————————
#   Fold    Adam Acc    Adam Prec   Adam Rec    Adam F1     RMSprop Acc RMSprop PrecRMSprop Rec RMSprop F1
#   ———————————————————————————————————————————————————————————————————————————————————————————————
#   Fold 1  0.7700      0.7184      0.7500      0.7265      0.7711      0.7182      0.7418      0.7264
#   Fold 2  0.7019      0.6529      0.6776      0.6537      0.7333      0.6717      0.6891      0.6768
#   Fold 3  0.7711      0.7210      0.7545      0.7278      0.7570      0.6912      0.7056      0.6959
#   Fold 4  0.7459      0.6916      0.7180      0.6978      0.7319      0.6753      0.6980      0.6811
#   Fold 5  0.7838      0.7266      0.7508      0.7341      0.7384      0.6956      0.7323      0.6967
#   ———————————————————————————————————————————————————————————————————————————————————————————————
#   Rata    0.7545      0.7021      0.7302      0.7080      0.7463      0.6904      0.7134      0.6954
#
# Optimizer terbaik (rata-rata Accuracy): Adam (0.7545)

# %%
print("Confusion Matrix")
print("=" * 50)

nama_kelas_list = list(LabelEncode.classes_)

for nama_opt in daftar_optimizer:
    print(f"\n{'='*65}")
    print(f"OPTIMIZER: {nama_opt}")
    print(f"{'='*65}")

    # TABEL EVALUASI PER FOLD
    print(f"\n  {'Fold':<8} {'TP':>5} {'TN':>6} {'FP':>5} {'FN':>5}"
          f"  {'Acc':>7} {'Prec':>7} {'Rec':>7} {'F1':>7}")
    print("  " + "—" * 65)

    # Simpan untuk grafik & rata-rata
    fold_data = []

    for fold in range(N_FOLDS):
        y_true_f = np.array(hasil[nama_opt]['y_true_fold'][fold])
        y_pred_f = np.array(hasil[nama_opt]['y_pred_fold'][fold])
        cm = confusion_matrix(y_true_f, y_pred_f, labels=range(NUM_CLASSES))

        # Agregasi TP/TN/FP/FN (jumlah dari semua kelas)
        TP_agg, TN_agg, FP_agg, FN_agg = 0, 0, 0, 0
        prec_k, rec_k, f1_k = [], [], []

        for k in range(NUM_CLASSES):
            TP = cm[k, k]
            FP = cm[:, k].sum() - TP
            FN = cm[k, :].sum() - TP
            TN = cm.sum() - TP - FP - FN

            TP_agg += TP; TN_agg += TN
            FP_agg += FP; FN_agg += FN

            prec = TP / (TP + FP) if (TP + FP) > 0 else 0
            rec  = TP / (TP + FN) if (TP + FN) > 0 else 0
            f1   = 2*prec*rec / (prec + rec) if (prec + rec) > 0 else 0
            prec_k.append(prec); rec_k.append(rec); f1_k.append(f1)

        # Macro average
        acc        = accuracy_score(y_true_f, y_pred_f)
        macro_prec = np.mean(prec_k)
        macro_rec  = np.mean(rec_k)
        macro_f1   = np.mean(f1_k)

        fold_data.append({
            'TP': TP_agg, 
            'TN': TN_agg, 
            'FP': FP_agg, 
            'FN': FN_agg,
            'acc': acc, 
            'prec': macro_prec, 
            'rec': macro_rec, 
            'f1': macro_f1,
            'cm': cm, 
            'y_true': y_true_f, 
            'y_pred': y_pred_f,
            'prec_per_kelas': prec_k, 
            'rec_per_kelas': rec_k, 
            'f1_per_kelas': f1_k,
        })

        print(f"  Fold {fold+1:<3} {TP_agg:>5} {TN_agg:>6} {FP_agg:>5} {FN_agg:>5}"
              f"  {acc:>7.4f} {macro_prec:>7.4f} {macro_rec:>7.4f} {macro_f1:>7.4f}")

    # Rata-rata
    print("  " + "—" * 65)
    print(f"  {'Rata':<8} {'':>5} {'':>6} {'':>5} {'':>5}"
          f"  {np.mean([d['acc'] for d in fold_data]):>7.4f}"
          f" {np.mean([d['prec'] for d in fold_data]):>7.4f}"
          f"  {np.mean([d['rec'] for d in fold_data]):>7.4f}"
          f" {np.mean([d['f1'] for d in fold_data]):>7.4f}")


    # CONFUSION MATRIX PER FOLD
    fig, axes = plt.subplots(1, N_FOLDS, figsize=(4.5 * N_FOLDS, 4.5))
    fig.suptitle(f'Confusion Matrix per Fold — {nama_opt}',
                 fontsize=14, fontweight='bold')

    for fold in range(N_FOLDS):
        cm = fold_data[fold]['cm']
        ax = axes[fold]

        im = ax.imshow(cm, cmap='Blues')
        ax.set_title(f'Fold {fold+1}', fontweight='bold', fontsize=12)
        ax.set_xlabel('Prediksi')
        if fold == 0:
            ax.set_ylabel('Aktual')
        ax.set_xticks(range(NUM_CLASSES))
        ax.set_yticks(range(NUM_CLASSES))
        ax.set_xticklabels(nama_kelas_list, fontsize=9)
        ax.set_yticklabels(nama_kelas_list, fontsize=9)

        for i in range(NUM_CLASSES):
            for j in range(NUM_CLASSES):
                ax.text(j, i, str(cm[i, j]), ha='center', va='center',
                        fontsize=12, fontweight='bold',
                        color='white' if cm[i, j] > cm.max()/2 else 'black')

    plt.tight_layout()
    plt.savefig(f'confusion_matrix_perfold_{nama_opt}.png', dpi=150, bbox_inches='tight')
    plt.show()

    # DETAIL PERHITUNGAN PER KELAS PER FOLD
    for fold in range(N_FOLDS):
        d  = fold_data[fold]
        cm = d['cm']

        print(f"\n  --- Fold {fold+1} ---")
        print(f"  Confusion Matrix 3x3 (Aktual \\ Prediksi):")
        print(f"  {'':>10}" + "".join(f"{k:>6}" for k in nama_kelas_list))
        for i, k in enumerate(nama_kelas_list):
            print(f"  {k:>10}" + "".join(f"{cm[i,j]:>6}" for j in range(NUM_CLASSES)))

        print(f"\n  Diketahui:")
        print(f"  Total TP = " + " + ".join(f"{cm[k,k]}" for k in range(NUM_CLASSES))
              + f" = {d['TP']}")
        print(f"  Total FP = " + " + ".join(f"{cm[:,k].sum()-cm[k,k]}" for k in range(NUM_CLASSES))
              + f" = {d['FP']}")
        print(f"  Total FN = " + " + ".join(f"{cm[k,:].sum()-cm[k,k]}" for k in range(NUM_CLASSES))
              + f" = {d['FN']}")

        # Accuracy
        total = len(d['y_true'])
        print(f"\n  a. Accuracy = {d['TP']} / {total} = {d['acc']:.4f}")

        # Precision per kelas
        print(f"\n  b. Precision (per kelas):")
        for k in range(NUM_CLASSES):
            TP_k = cm[k, k]; FP_k = cm[:, k].sum() - TP_k
            print(f"     {nama_kelas_list[k]}: {TP_k}/({TP_k}+{FP_k})"
                  f" = {d['prec_per_kelas'][k]:.4f}")
        print(f"     Macro Precision = {d['prec']:.4f}")

        # Recall per kelas
        print(f"\n  c. Recall (per kelas):")
        for k in range(NUM_CLASSES):
            TP_k = cm[k, k]; FN_k = cm[k, :].sum() - TP_k
            print(f"     {nama_kelas_list[k]}: {TP_k}/({TP_k}+{FN_k})"
                  f" = {d['rec_per_kelas'][k]:.4f}")
        print(f"     Macro Recall = {d['rec']:.4f}")

        # F1-Score per kelas
        print(f"\n  d. F1-Score (per kelas):")
        for k in range(NUM_CLASSES):
            p = d['prec_per_kelas'][k]; r = d['rec_per_kelas'][k]
            print(f"     {nama_kelas_list[k]}: 2×({p:.4f}×{r:.4f})"
                  f"/({p:.4f}+{r:.4f}) = {d['f1_per_kelas'][k]:.4f}")
        print(f"     Macro F1-Score = {d['f1']:.4f}")

        print(f"\n  Hasil Fold {fold+1}: TP={d['TP']}  TN={d['TN']}"
              f"  FP={d['FP']}  FN={d['FN']}")
        print(f"  Acc={d['acc']:.4f}  Prec={d['prec']:.4f}"
              f"  Rec={d['rec']:.4f}  F1={d['f1']:.4f}")
        print("  " + "—" * 55)
# Out:
# Confusion Matrix
# ==================================================
#
# =================================================================
# OPTIMIZER: Adam
# =================================================================
#
#   Fold        TP     TN    FP    FN      Acc    Prec     Rec      F1
#   —————————————————————————————————————————————————————————————————
#   Fold 1     713   1639   213   213   0.7700  0.7184  0.7500  0.7265
#   Fold 2     650   1576   276   276   0.7019  0.6529  0.6776  0.6537
#   Fold 3     714   1640   212   212   0.7711  0.7210  0.7545  0.7278
#   Fold 4     690   1615   235   235   0.7459  0.6916  0.7180  0.6978
#   Fold 5     725   1650   200   200   0.7838  0.7266  0.7508  0.7341
#   —————————————————————————————————————————————————————————————————
#   Rata                                0.7545  0.7021   0.7302  0.7080
#   --- Fold 1 ---
#   Confusion Matrix 3x3 (Aktual \ Prediksi):
#                BCC   MEL   SCC
#          BCC   290    39    71
#          MEL    36   337    27
#          SCC    30    10    86
#
#   Diketahui:
#   Total TP = 290 + 337 + 86 = 713
#   Total FP = 66 + 49 + 98 = 213
#   Total FN = 110 + 63 + 40 = 213
#
#   a. Accuracy = 713 / 926 = 0.7700
#
#   b. Precision (per kelas):
#      BCC: 290/(290+66) = 0.8146
#      MEL: 337/(337+49) = 0.8731
#      SCC: 86/(86+98) = 0.4674
#      Macro Precision = 0.7184
#
#   c. Recall (per kelas):
#      BCC: 290/(290+110) = 0.7250
#      MEL: 337/(337+63) = 0.8425
#      SCC: 86/(86+40) = 0.6825
#      Macro Recall = 0.7500
#
#   d. F1-Score (per kelas):
#      BCC: 2×(0.8146×0.7250)/(0.8146+0.7250) = 0.7672
#      MEL: 2×(0.8731×0.8425)/(0.8731+0.8425) = 0.8575
#      SCC: 2×(0.4674×0.6825)/(0.4674+0.6825) = 0.5548
#      Macro F1-Score = 0.7265
#
#   Hasil Fold 1: TP=713  TN=1639  FP=213  FN=213
#   Acc=0.7700  Prec=0.7184  Rec=0.7500  F1=0.7265
#   ———————————————————————————————————————————————————————
#
#   --- Fold 2 ---
#   Confusion Matrix 3x3 (Aktual \ Prediksi):
#                BCC   MEL   SCC
#          BCC   259    47    94
#          MEL    45   316    39
#          SCC    31    20    75
#
#   Diketahui:
#   Total TP = 259 + 316 + 75 = 650
#   Total FP = 76 + 67 + 133 = 276
#   Total FN = 141 + 84 + 51 = 276
#
#   a. Accuracy = 650 / 926 = 0.7019
#
#   b. Precision (per kelas):
#      BCC: 259/(259+76) = 0.7731
#      MEL: 316/(316+67) = 0.8251
#      SCC: 75/(75+133) = 0.3606
#      Macro Precision = 0.6529
#
#   c. Recall (per kelas):
#      BCC: 259/(259+141) = 0.6475
#      MEL: 316/(316+84) = 0.7900
#      SCC: 75/(75+51) = 0.5952
#      Macro Recall = 0.6776
#
#   d. F1-Score (per kelas):
#      BCC: 2×(0.7731×0.6475)/(0.7731+0.6475) = 0.7048
#      MEL: 2×(0.8251×0.7900)/(0.8251+0.7900) = 0.8072
#      SCC: 2×(0.3606×0.5952)/(0.3606+0.5952) = 0.4491
#      Macro F1-Score = 0.6537
#
#   Hasil Fold 2: TP=650  TN=1576  FP=276  FN=276
#   Acc=0.7019  Prec=0.6529  Rec=0.6776  F1=0.6537
#   ———————————————————————————————————————————————————————
#
#   --- Fold 3 ---
#   Confusion Matrix 3x3 (Aktual \ Prediksi):
#                BCC   MEL   SCC
#          BCC   283    43    74
#          MEL    29   343    28
#          SCC    24    14    88
#
#   Diketahui:
#   Total TP = 283 + 343 + 88 = 714
#   Total FP = 53 + 57 + 102 = 212
#   Total FN = 117 + 57 + 38 = 212
#
#   a. Accuracy = 714 / 926 = 0.7711
#
#   b. Precision (per kelas):
#      BCC: 283/(283+53) = 0.8423
#      MEL: 343/(343+57) = 0.8575
#      SCC: 88/(88+102) = 0.4632
#      Macro Precision = 0.7210
#
#   c. Recall (per kelas):
#      BCC: 283/(283+117) = 0.7075
#      MEL: 343/(343+57) = 0.8575
#      SCC: 88/(88+38) = 0.6984
#      Macro Recall = 0.7545
#
#   d. F1-Score (per kelas):
#      BCC: 2×(0.8423×0.7075)/(0.8423+0.7075) = 0.7690
#      MEL: 2×(0.8575×0.8575)/(0.8575+0.8575) = 0.8575
#      SCC: 2×(0.4632×0.6984)/(0.4632+0.6984) = 0.5570
#      Macro F1-Score = 0.7278
#
#   Hasil Fold 3: TP=714  TN=1640  FP=212  FN=212
#   Acc=0.7711  Prec=0.7210  Rec=0.7545  F1=0.7278
#   ———————————————————————————————————————————————————————
#
#   --- Fold 4 ---
#   Confusion Matrix 3x3 (Aktual \ Prediksi):
#                BCC   MEL   SCC
#          BCC   273    50    77
#          MEL    39   339    22
#          SCC    27    20    78
#
#   Diketahui:
#   Total TP = 273 + 339 + 78 = 690
#   Total FP = 66 + 70 + 99 = 235
#   Total FN = 127 + 61 + 47 = 235
#
#   a. Accuracy = 690 / 925 = 0.7459
#
#   b. Precision (per kelas):
#      BCC: 273/(273+66) = 0.8053
#      MEL: 339/(339+70) = 0.8289
#      SCC: 78/(78+99) = 0.4407
#      Macro Precision = 0.6916
#
#   c. Recall (per kelas):
#      BCC: 273/(273+127) = 0.6825
#      MEL: 339/(339+61) = 0.8475
#      SCC: 78/(78+47) = 0.6240
#      Macro Recall = 0.7180
#
#   d. F1-Score (per kelas):
#      BCC: 2×(0.8053×0.6825)/(0.8053+0.6825) = 0.7388
#      MEL: 2×(0.8289×0.8475)/(0.8289+0.8475) = 0.8381
#      SCC: 2×(0.4407×0.6240)/(0.4407+0.6240) = 0.5166
#      Macro F1-Score = 0.6978
#
#   Hasil Fold 4: TP=690  TN=1615  FP=235  FN=235
#   Acc=0.7459  Prec=0.6916  Rec=0.7180  F1=0.6978
#   ———————————————————————————————————————————————————————
#
#   --- Fold 5 ---
#   Confusion Matrix 3x3 (Aktual \ Prediksi):
#                BCC   MEL   SCC
#          BCC   297    38    65
#          MEL    31   348    21
#          SCC    28    17    80
#
#   Diketahui:
#   Total TP = 297 + 348 + 80 = 725
#   Total FP = 59 + 55 + 86 = 200
#   Total FN = 103 + 52 + 45 = 200
#
#   a. Accuracy = 725 / 925 = 0.7838
#
#   b. Precision (per kelas):
#      BCC: 297/(297+59) = 0.8343
#      MEL: 348/(348+55) = 0.8635
#      SCC: 80/(80+86) = 0.4819
#      Macro Precision = 0.7266
#
#   c. Recall (per kelas):
#      BCC: 297/(297+103) = 0.7425
#      MEL: 348/(348+52) = 0.8700
#      SCC: 80/(80+45) = 0.6400
#      Macro Recall = 0.7508
#
#   d. F1-Score (per kelas):
#      BCC: 2×(0.8343×0.7425)/(0.8343+0.7425) = 0.7857
#      MEL: 2×(0.8635×0.8700)/(0.8635+0.8700) = 0.8667
#      SCC: 2×(0.4819×0.6400)/(0.4819+0.6400) = 0.5498
#      Macro F1-Score = 0.7341
#
#   Hasil Fold 5: TP=725  TN=1650  FP=200  FN=200
#   Acc=0.7838  Prec=0.7266  Rec=0.7508  F1=0.7341
#   ———————————————————————————————————————————————————————
#
# =================================================================
# OPTIMIZER: RMSprop
# =================================================================
#
#   Fold        TP     TN    FP    FN      Acc    Prec     Rec      F1
#   —————————————————————————————————————————————————————————————————
#   Fold 1     714   1640   212   212   0.7711  0.7182  0.7418  0.7264
#   Fold 2     679   1605   247   247   0.7333  0.6717  0.6891  0.6768
#   Fold 3     701   1627   225   225   0.7570  0.6912  0.7056  0.6959
#   Fold 4     677   1602   248   248   0.7319  0.6753  0.6980  0.6811
#   Fold 5     683   1608   242   242   0.7384  0.6956  0.7323  0.6967
#   —————————————————————————————————————————————————————————————————
#   Rata                                0.7463  0.6904   0.7134  0.6954
#   --- Fold 1 ---
#   Confusion Matrix 3x3 (Aktual \ Prediksi):
#                BCC   MEL   SCC
#          BCC   299    37    64
#          MEL    47   334    19
#          SCC    31    14    81
#
#   Diketahui:
#   Total TP = 299 + 334 + 81 = 714
#   Total FP = 78 + 51 + 83 = 212
#   Total FN = 101 + 66 + 45 = 212
#
#   a. Accuracy = 714 / 926 = 0.7711
#
#   b. Precision (per kelas):
#      BCC: 299/(299+78) = 0.7931
#      MEL: 334/(334+51) = 0.8675
#      SCC: 81/(81+83) = 0.4939
#      Macro Precision = 0.7182
#
#   c. Recall (per kelas):
#      BCC: 299/(299+101) = 0.7475
#      MEL: 334/(334+66) = 0.8350
#      SCC: 81/(81+45) = 0.6429
#      Macro Recall = 0.7418
#
#   d. F1-Score (per kelas):
#      BCC: 2×(0.7931×0.7475)/(0.7931+0.7475) = 0.7696
#      MEL: 2×(0.8675×0.8350)/(0.8675+0.8350) = 0.8510
#      SCC: 2×(0.4939×0.6429)/(0.4939+0.6429) = 0.5586
#      Macro F1-Score = 0.7264
#
#   Hasil Fold 1: TP=714  TN=1640  FP=212  FN=212
#   Acc=0.7711  Prec=0.7182  Rec=0.7418  F1=0.7264
#   ———————————————————————————————————————————————————————
#
#   --- Fold 2 ---
#   Confusion Matrix 3x3 (Aktual \ Prediksi):
#                BCC   MEL   SCC
#          BCC   281    42    77
#          MEL    49   330    21
#          SCC    32    26    68
#
#   Diketahui:
#   Total TP = 281 + 330 + 68 = 679
#   Total FP = 81 + 68 + 98 = 247
#   Total FN = 119 + 70 + 58 = 247
#
#   a. Accuracy = 679 / 926 = 0.7333
#
#   b. Precision (per kelas):
#      BCC: 281/(281+81) = 0.7762
#      MEL: 330/(330+68) = 0.8291
#      SCC: 68/(68+98) = 0.4096
#      Macro Precision = 0.6717
#
#   c. Recall (per kelas):
#      BCC: 281/(281+119) = 0.7025
#      MEL: 330/(330+70) = 0.8250
#      SCC: 68/(68+58) = 0.5397
#      Macro Recall = 0.6891
#
#   d. F1-Score (per kelas):
#      BCC: 2×(0.7762×0.7025)/(0.7762+0.7025) = 0.7375
#      MEL: 2×(0.8291×0.8250)/(0.8291+0.8250) = 0.8271
#      SCC: 2×(0.4096×0.5397)/(0.4096+0.5397) = 0.4658
#      Macro F1-Score = 0.6768
#
#   Hasil Fold 2: TP=679  TN=1605  FP=247  FN=247
#   Acc=0.7333  Prec=0.6717  Rec=0.6891  F1=0.6768
#   ———————————————————————————————————————————————————————
#
#   --- Fold 3 ---
#   Confusion Matrix 3x3 (Aktual \ Prediksi):
#                BCC   MEL   SCC
#          BCC   299    35    66
#          MEL    38   335    27
#          SCC    43    16    67
#
#   Diketahui:
#   Total TP = 299 + 335 + 67 = 701
#   Total FP = 81 + 51 + 93 = 225
#   Total FN = 101 + 65 + 59 = 225
#
#   a. Accuracy = 701 / 926 = 0.7570
#
#   b. Precision (per kelas):
#      BCC: 299/(299+81) = 0.7868
#      MEL: 335/(335+51) = 0.8679
#      SCC: 67/(67+93) = 0.4188
#      Macro Precision = 0.6912
#
#   c. Recall (per kelas):
#      BCC: 299/(299+101) = 0.7475
#      MEL: 335/(335+65) = 0.8375
#      SCC: 67/(67+59) = 0.5317
#      Macro Recall = 0.7056
#
#   d. F1-Score (per kelas):
#      BCC: 2×(0.7868×0.7475)/(0.7868+0.7475) = 0.7667
#      MEL: 2×(0.8679×0.8375)/(0.8679+0.8375) = 0.8524
#      SCC: 2×(0.4188×0.5317)/(0.4188+0.5317) = 0.4685
#      Macro F1-Score = 0.6959
#
#   Hasil Fold 3: TP=701  TN=1627  FP=225  FN=225
#   Acc=0.7570  Prec=0.6912  Rec=0.7056  F1=0.6959
#   ———————————————————————————————————————————————————————
#
#   --- Fold 4 ---
#   Confusion Matrix 3x3 (Aktual \ Prediksi):
#                BCC   MEL   SCC
#          BCC   282    48    70
#          MEL    45   322    33
#          SCC    31    21    73
#
#   Diketahui:
#   Total TP = 282 + 322 + 73 = 677
#   Total FP = 76 + 69 + 103 = 248
#   Total FN = 118 + 78 + 52 = 248
#
#   a. Accuracy = 677 / 925 = 0.7319
#
#   b. Precision (per kelas):
#      BCC: 282/(282+76) = 0.7877
#      MEL: 322/(322+69) = 0.8235
#      SCC: 73/(73+103) = 0.4148
#      Macro Precision = 0.6753
#
#   c. Recall (per kelas):
#      BCC: 282/(282+118) = 0.7050
#      MEL: 322/(322+78) = 0.8050
#      SCC: 73/(73+52) = 0.5840
#      Macro Recall = 0.6980
#
#   d. F1-Score (per kelas):
#      BCC: 2×(0.7877×0.7050)/(0.7877+0.7050) = 0.7441
#      MEL: 2×(0.8235×0.8050)/(0.8235+0.8050) = 0.8142
#      SCC: 2×(0.4148×0.5840)/(0.4148+0.5840) = 0.4850
#      Macro F1-Score = 0.6811
#
#   Hasil Fold 4: TP=677  TN=1602  FP=248  FN=248
#   Acc=0.7319  Prec=0.6753  Rec=0.6980  F1=0.6811
#   ———————————————————————————————————————————————————————
#
#   --- Fold 5 ---
#   Confusion Matrix 3x3 (Aktual \ Prediksi):
#                BCC   MEL   SCC
#          BCC   263    45    92
#          MEL    31   331    38
#          SCC    23    13    89
#
#   Diketahui:
#   Total TP = 263 + 331 + 89 = 683
#   Total FP = 54 + 58 + 130 = 242
#   Total FN = 137 + 69 + 36 = 242
#
#   a. Accuracy = 683 / 925 = 0.7384
#
#   b. Precision (per kelas):
#      BCC: 263/(263+54) = 0.8297
#      MEL: 331/(331+58) = 0.8509
#      SCC: 89/(89+130) = 0.4064
#      Macro Precision = 0.6956
#
#   c. Recall (per kelas):
#      BCC: 263/(263+137) = 0.6575
#      MEL: 331/(331+69) = 0.8275
#      SCC: 89/(89+36) = 0.7120
#      Macro Recall = 0.7323
#
#   d. F1-Score (per kelas):
#      BCC: 2×(0.8297×0.6575)/(0.8297+0.6575) = 0.7336
#      MEL: 2×(0.8509×0.8275)/(0.8509+0.8275) = 0.8390
#      SCC: 2×(0.4064×0.7120)/(0.4064+0.7120) = 0.5174
#      Macro F1-Score = 0.6967
#
#   Hasil Fold 5: TP=683  TN=1608  FP=242  FN=242
#   Acc=0.7384  Prec=0.6956  Rec=0.7323  F1=0.6967
#   ———————————————————————————————————————————————————————

# %% [markdown]
# <div style="
#     padding-left: 18px;
#     border-left: 4px solid #111827;
#     margin-top: 25px;
# ">
#
# <h3 style="
#     margin-bottom: 8px;
#     font-size: 24px;
#     font-weight: 600;
# "> Tahap 8 - Grad-Cam
# </h3>
#
# <p style="
#     margin-top: 0;
#     color: #555;
#     line-height: 1.7;
# ">Visualisasi Model dengan Grad-cam</p>
#
# </div>

# %%
print("GRAD-CAM")
print("=" * 50)

# Load model terbaik dari optimizer terbaik
model_terbaik = tf.keras.models.load_model(
    f'/kaggle/working/model_terbaik_mobilenetv3_partial_LR2{opt_terbaik}.keras',
     custom_objects={'focal_loss_function': focal_loss_function}
)
print(f"Model '{opt_terbaik}' berhasil di-load!")
print(f"Info: {best_model_info_per_opt[opt_terbaik]}")

#Fungsi Gradcam
def buat_gradcam(model, gambar, indeks_kelas):

    # 1. Buat grad_model: input[conv_output, prediksi]
    grad_model = tf.keras.Model(
        inputs  = model.inputs,
        outputs = [model.get_layer(GRADCAM_LAYER).output, model.output]
    )

    # 2. Forward pass dan rekam gradient
    with tf.GradientTape() as tape:
        inp              = tf.cast(gambar, tf.float32)
        conv_out, preds  = grad_model(inp, training=False)
        skor_kelas       = preds[:, indeks_kelas]

    # 3. Hitung gradient
    grads = tape.gradient(skor_kelas, conv_out)

    if grads is None:
        print(f"Tolong cek kembali nama layer '{GRADCAM_LAYER}'")
        return np.zeros((IMG_SIZE, IMG_SIZE))

    # 4. Buat heatmap
    bobot   = tf.reduce_mean(grads, axis=(0, 1, 2))
    heatmap = tf.reduce_sum(conv_out[0] * bobot, axis=-1)
    heatmap = tf.nn.relu(heatmap)
    heatmap = heatmap / (tf.reduce_max(heatmap) + 1e-8)

    return cv2.resize(heatmap.numpy(), (IMG_SIZE, IMG_SIZE))
# Out:
# GRAD-CAM
# ==================================================
# Model 'Adam' berhasil di-load!
# Info: {'optimizer': 'Adam', 'fold': 5, 'val_acc': 0.7837837837837838, 'val_macro_f1': 0.7340973843586469}

# %%
def tampilkan_gradcam(gambar_display, heatmap, label_asli, label_prediksi, ax):
    heatmap_u8    = np.uint8(255 * heatmap)
    heatmap_color = cv2.applyColorMap(heatmap_u8, cv2.COLORMAP_JET)
    heatmap_color = cv2.cvtColor(heatmap_color, cv2.COLOR_BGR2RGB) / 255.0

    overlay = gambar_display * 0.75 + heatmap_color * 0.25
    overlay = np.clip(overlay, 0, 1)

    ax.imshow(overlay)
    warna = 'green' if label_asli == label_prediksi else 'red'
    ax.set_title(f'Aktual: {label_asli}\nPrediksi: {label_prediksi}',
                 fontsize=9, color=warna, fontweight='bold')
    ax.axis('off')

print("—" * 50)
print("Menampilkan Grad-CAM (3 gambar per kelas)")
print("—" * 50)

fig, axes = plt.subplots(NUM_CLASSES, 3, figsize=(12, 4 * NUM_CLASSES))
fig.suptitle(
    f'Grad-CAM: Area yang Diperhatikan Model ({opt_terbaik})\n',
    fontsize=13, fontweight='bold'
)

for kelas_idx in range(NUM_CLASSES):
    nama_kelas = LabelEncode.classes_[kelas_idx]
    idx_kelas  = np.where(y_encoded == kelas_idx)[0]

    # Prioritas: ambil 3 sampel yang prediksinya BENAR
    sampel = []
    for idx in idx_kelas:
        if len(sampel) >= 3:
            break
        inp  = preprocess_input(X[idx:idx+1].astype(np.float32))
        pred = np.argmax(model_terbaik.predict(inp, verbose=0)[0])
        if pred == kelas_idx:
            sampel.append(idx)

    # Fallback kalau prediksi benar < 3
    if len(sampel) < 3:
        sisa   = [i for i in idx_kelas if i not in sampel]
        sampel += list(sisa[:3 - len(sampel)])

    for col, idx in enumerate(sampel[:3]):
        gambar_model  = preprocess_input(X[idx:idx+1].astype(np.float32))
        gambar_tampil = X[idx].astype(np.float32) / 255.0
        pred_proba    = model_terbaik.predict(gambar_model, verbose=0)
        pred_kelas    = np.argmax(pred_proba[0])
        nama_pred     = LabelEncode.classes_[pred_kelas]

        heatmap = buat_gradcam(model_terbaik, gambar_model, pred_kelas)
        tampilkan_gradcam(gambar_tampil, heatmap, nama_kelas,
                          nama_pred, axes[kelas_idx, col])

    axes[kelas_idx, 0].set_ylabel(nama_kelas, fontsize=11, fontweight='bold')

plt.tight_layout()
plt.savefig('gradcam_per_kelas.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# ——————————————————————————————————————————————————
# Menampilkan Grad-CAM (3 gambar per kelas)
# ——————————————————————————————————————————————————

# %%
print("Grad-CAM: Prediksi Benar vs Salah (Semua Kelas)")
print("=" * 50)

fig, axes = plt.subplots(NUM_CLASSES * 2, 4, figsize=(16, 6 * NUM_CLASSES))
fig.suptitle('Grad-CAM: Prediksi Benar dan Prediksi Salah untuk semua kelas\n',
    fontsize=13, fontweight='bold'
)

for kelas_idx in range(NUM_CLASSES):
    nama_kelas               = LabelEncode.classes_[kelas_idx]
    benar_list, salah_list   = [], []

    # Kumpulkan 4 sampel benar dan 4 sampel salah untuk kelas ini
    for idx in np.where(y_encoded == kelas_idx)[0]:
        if len(benar_list) >= 4 and len(salah_list) >= 4:
            break
        inp        = preprocess_input(X[idx:idx+1].astype(np.float32))
        pred_kelas = np.argmax(model_terbaik.predict(inp, verbose=0)[0])

        if pred_kelas == kelas_idx and len(benar_list) < 4:
            benar_list.append((idx, pred_kelas))
        elif pred_kelas != kelas_idx and len(salah_list) < 4:
            salah_list.append((idx, pred_kelas))

    # Baris atas = benar, baris bawah = salah
    baris_benar = kelas_idx * 2
    baris_salah = kelas_idx * 2 + 1

    # Label baris di kolom pertama
    axes[baris_benar, 0].set_ylabel(f'{nama_kelas}\nBenar', fontsize=10, fontweight='bold')
    axes[baris_salah, 0].set_ylabel(f'{nama_kelas}\nSalah', fontsize=10, fontweight='bold')

    for col in range(4):
        # Baris Benar
        if col < len(benar_list):
            idx, pred_kelas   = benar_list[col]
            gambar_model      = preprocess_input(X[idx:idx+1].astype(np.float32))
            gambar_tampil     = X[idx].astype(np.float32) / 255.0
            nama_pred         = LabelEncode.classes_[pred_kelas]
            heatmap           = buat_gradcam(model_terbaik, gambar_model, pred_kelas)
            tampilkan_gradcam(gambar_tampil, heatmap, nama_kelas, nama_pred, axes[baris_benar, col])
        else:
            axes[baris_benar, col].axis('off')  # kosong kalau sampel kurang dari 4

        # Baris Salah
        if col < len(salah_list):
            idx, pred_kelas   = salah_list[col]
            gambar_model      = preprocess_input(X[idx:idx+1].astype(np.float32))
            gambar_tampil     = X[idx].astype(np.float32) / 255.0
            nama_pred         = LabelEncode.classes_[pred_kelas]
            heatmap           = buat_gradcam(model_terbaik, gambar_model, pred_kelas)
            tampilkan_gradcam(gambar_tampil, heatmap, nama_kelas, nama_pred, axes[baris_salah, col])
        else:
            axes[baris_salah, col].axis('off')  # kosong kalau sampel kurang dari 4

plt.tight_layout()
plt.savefig('gradcam_benar_vs_salah.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# Grad-CAM: Prediksi Benar vs Salah (Semua Kelas)
# ==================================================

# %%
print("Simpan Hasil")
print("=" * 50)

# Simpan hasil training (backup numpy)
np.save('/kaggle/working/hasil_training_mobilenetv3_LR2_partial.npy', hasil)

nama_kelas_list = list(LabelEncode.classes_)


# FUNGSI: Hitung metrik per fold (format tabel)
def hitung_metrik_perfold(y_true_fold, y_pred_fold, num_classes):
    rows_summary = []
    nama_kelas   = list(LabelEncode.classes_)

    for fold_idx, (yt, yp) in enumerate(zip(y_true_fold, y_pred_fold)):
        yt = np.array(yt)
        yp = np.array(yp)
        cm = confusion_matrix(yt, yp, labels=list(range(num_classes)))

        acc = accuracy_score(yt, yp)

        TP_agg, TN_agg, FP_agg, FN_agg = 0, 0, 0, 0
        prec_list, rec_list, f1_list = [], [], []

        for k in range(num_classes):
            TP = cm[k, k]
            FP = cm[:, k].sum() - TP
            FN = cm[k, :].sum() - TP
            TN = cm.sum() - TP - FP - FN

            TP_agg += TP; TN_agg += TN
            FP_agg += FP; FN_agg += FN

            prec = TP / (TP + FP) if (TP + FP) > 0 else 0
            rec  = TP / (TP + FN) if (TP + FN) > 0 else 0
            f1   = 2*prec*rec / (prec + rec) if (prec + rec) > 0 else 0

            prec_list.append(prec)
            rec_list.append(rec)
            f1_list.append(f1)

        rows_summary.append({
            'Fold'              : f'Fold {fold_idx + 1}',
            'TP'                : int(TP_agg),
            'TN'                : int(TN_agg),
            'FP'                : int(FP_agg),
            'FN'                : int(FN_agg),
            'Accuracy'          : round(acc, 4),
            'Precision (Macro)' : round(np.mean(prec_list), 4),
            'Recall (Macro)'    : round(np.mean(rec_list), 4),
            'F1-Score (Macro)'  : round(np.mean(f1_list), 4),
        })

    df_summary = pd.DataFrame(rows_summary)

    # Baris rata-rata
    cols_numerik = [c for c in df_summary.columns if c not in ['Fold','TP','TN','FP','FN']]
    rata = {'Fold': 'Rata-Rata', 'TP': '', 'TN': '', 'FP': '', 'FN': ''}
    for col in cols_numerik:
        rata[col] = round(df_summary[col].mean(), 4)
    df_summary = pd.concat([df_summary, pd.DataFrame([rata])], ignore_index=True)

    return df_summary


# Sheet 1: Akurasi & Macro F1 per Fold
data_akurasi = {}
for nama_opt in daftar_optimizer:
    data_akurasi[f'{nama_opt} Acc']      = hasil[nama_opt]['val_acc']
    data_akurasi[f'{nama_opt} Macro F1'] = hasil[nama_opt]['val_macro_f1']

df_akurasi = pd.DataFrame(data_akurasi)
df_akurasi.index = [f'Fold {i+1}' for i in range(N_FOLDS)]
rata_row = {}
for col in df_akurasi.columns:
    rata_row[col] = df_akurasi[col].mean()
df_akurasi.loc['Rata-rata'] = rata_row


# Sheet 2-3: Evaluasi per Fold (TP/TN/FP/FN + metrik macro)
df_eval_fold = {}
for nama_opt in daftar_optimizer:
    df_eval_fold[nama_opt] = hitung_metrik_perfold(
        hasil[nama_opt]['y_true_fold'],
        hasil[nama_opt]['y_pred_fold'],
        NUM_CLASSES
    )

# Simpan ke Excel
path_excel = '/kaggle/working/hasil_mobilenetv3_LR2_partial.xlsx'

with pd.ExcelWriter(path_excel, engine='openpyxl') as writer:
    # Sheet 1: Akurasi & Macro F1 per Fold
    df_akurasi.to_excel(writer, sheet_name='Akurasi dan F1 per Fold')

    # Sheet 2-3: Evaluasi per Fold (format seperti laporan)
    for nama_opt in daftar_optimizer:
        df_eval_fold[nama_opt].to_excel(
            writer,
            sheet_name=f'Evaluasi Fold {nama_opt}',
            index=False
        )

# Rekap Akhir
print("REKAP AKHIR")
print(" ")
print(f"nModel     : MobileNetV3-Large (Transfer Learning)")
print(f"Validation : Stratified {N_FOLDS}-Fold Cross Validation")
print(f"Optimizer  : {daftar_optimizer}")

print( )
print(f"Hasil Rata-Rata per Optimizer:")
for nama_opt in daftar_optimizer:
    rata_acc = np.mean(hasil[nama_opt]['val_acc'])
    rata_f1  = np.mean(hasil[nama_opt]['val_macro_f1'])
    print(f"{nama_opt:<10}: Acc={rata_acc:.4f} | Macro F1={rata_f1:.4f}")

info_opt = best_model_info_per_opt[opt_terbaik]
print(" ")
print(f"Optimizer Terbaik (rata-rata Accuracy)")
print(f"Optimizer           : {opt_terbaik}")
print(f"Rata-rata Accuracy  : {rata_acc_per_opt[opt_terbaik]:.4f}")

print(" ")
print(f"Model yang Disimpan (fold dengan Accuracy tertinggi dari {opt_terbaik}):")
print(f"Fold               : {info_opt['fold']}")
print(f"Macro F1           : {info_opt['val_macro_f1']:.4f}")
print(f"Accuracy           : {info_opt['val_acc']:.4f}")
print(f"Training dan Evaluasi Model Selesai")
# Out:
# Simpan Hasil
# ==================================================
# REKAP AKHIR
#
# nModel     : MobileNetV3-Large (Transfer Learning)
# Validation : Stratified 5-Fold Cross Validation
# Optimizer  : ['Adam', 'RMSprop']
#
# Hasil Rata-Rata per Optimizer:
# Adam      : Acc=0.7545 | Macro F1=0.7080
# RMSprop   : Acc=0.7463 | Macro F1=0.6954
#
# Optimizer Terbaik (rata-rata Accuracy)
# Optimizer           : Adam
# Rata-rata Accuracy  : 0.7545
#
# Model yang Disimpan (fold dengan Accuracy tertinggi dari Adam):
# Fold               : 5
# Macro F1           : 0.7341
# Accuracy           : 0.7838
# Training dan Evaluasi Model Selesai
